# %% [markdown]
# # Portfolio Optimization by Shaping the Empirical Return Distribution
#
# ## Contents
# 1. Introduction
# 2. Mathematical problem statement
# 3. Implementation
# 4. Numerical example
# 5. Conclusion and directions for future work (scalability/parallel implementation)
#
# ## 1. Introduction
# In this notebook, we present a portfolio optimization technique that seeks to maximize the expected return while accounting for a finite number of constraints related to limits of the value at risk (VaR) at one or several significance levels. We will show that this formulation makes it possible to view portfolio optimization as maximizing the mean of a distibution, that is linearly parametrized by the portfolio weights, subject to keeping the left/negative tail of the distribution below a user-defined distribution, which we will refer to as the _risk profile_. We will then bring this problem to into the form of a mixed-integer linear programming (MILP) problem and demonstrate its efficacy on a simple numerical example. Finally, we conclude and show some directions for future work.
#
# ## 2. Mathematical problem statement
# Let $x \in \mathbb{R}^d, d \in \mathbb{N}$ denote a random variable describing the returns of $d$ assets. Let $D:=\{1,2,\dots,d\}$ and let $w\in W:=[0,1]^d$, such that $\sum_{i\in D} w_i = 1$, denote the weights of the assets in the portfolio. Then the (random) portfolio return is $\mathbb{E}[x]^\top w$, where $\mathbb{E}[\cdot]$ denotes the (element-wise) expectation operator associated with the distribution of each of the $d$ assets.
#
# Since the exact expectation is unavailable in practice, we replace $\mathbb{E}[x]$ in the expression above by $\bar{x}\in \mathbb{R}^d$, which denotes the empirical mean return of $x$ from $n\in \mathbb{N}$ observations $x^{(n)}$, i.e. $\bar{x}_i = \frac{1}{n}\sum_n x_i^{(n)}$. Hence, our maximisation objective becomes
# \begin{equation}
# \underset{w\in W}{\max}\bar{x}^\top w,
# \end{equation}
# which is linear in $w$. Let us now focus on the additional constraints that we seek to enforce. To this end, define two vector-valued parameters, $A\in [0,1]^k$ and $V\in\mathbb{R}^k$, where $k\in \mathbb{N}$. These are significance levels and corresponding values at risk. For example $A:=[0.01,0.05]$ and $V:=[-0.2,-0.1]$ would denote two VaR constraints, i.e. the 1% value at risk should be no smaller than -20% and the 5% value at risk should be no smaller than -10%. The constraints are then formulated, using an additional auxiliary variable $z^{(a)}\in [0,1]^n$ for all $a \in K:=\{1,2,\dots,k\}$, as
#
# \begin{align}
# \sum_{i\in N} z^{(a)}_i =& n A_a \text{, for all } a \in K,\\
# x_i^\top w \geq& V_a - M(1-z^{(a)}_i) \text{, for all } (a,i) \in K\times N,
# \end{align}
#
# where $M\in \mathbb{R}_++$ is sufficiently large, such that the inequality is always satisfied when $z^{(a)}_i=1$, for all choices of $w\in W$. Hence, this reformulation is also known as the big $M$ method. The first equality constraint ensures that for any VaR condition $a\in K$, the number of $z^{(a)}_i=1$ equal the fraction of samples $n$, i.e. $z^{(a)}$ is a selector variable that ensures that sufficiently many constraints need to be satisfied, i.e. if $z^{(a)}_i =1$, then the weights $w$ must be chosen such that $x_i^\top w \geq V_a$. This ensures that the VaR constraint is satisfied. Combining the objective and the constraints, we are now ready to implement this problem in Python.
#
# ## 3. Imlementation
# We use Pyhon and the $\texttt{mip}$ package (https://www.python-mip.com/) for mixed-integer linear programming and formulate the optimization routine by means of the following function:

# %%
def portfolioMILP(X, alpha=[0.05], VaR=[0], M = 2, max_weight=1, max_s = 10, abs_gap=1e-3):
    """
    Optimizes portfolio weights in a Mixed-Integer Linear Programming (MILP) setting, based on data X with n rows (observations)
    and d columns (assets), given a list (even if only a single value is desired!) of values at risk (VaR) at significance levels alpha, respectively. The variable
    "M" is used in a big M method trick to linearise the constraints. "max_weights" defines the maximum weight of an asset,
    "max_s" defines the maximum computation time, "abs_gap" defines the absolute gap between upper bound and lower bound on the solution,
    upon which the algorithm shall terminate.
    """
    
    n,d = X.shape
    X_mean = X.mean(axis=0)
    print(f"Optimizing over {d} assets using {n} samples")
    
    n_alpha = len(alpha)
    V=[[] for i in range(n_alpha)]
    
    m = Model(solver_name=CBC)
    m.max_mip_gap_abs = abs_gap
    
    w = [ m.add_var(var_type=CONTINUOUS) for dd in range(d) ] #decision variables (asset weights)
    m.objective = mip.minimize(-xsum(w[dd]*X_mean[dd] for dd in range(d))) #objective function
    m += xsum(w[dd] for dd in range(d)) == 1 #asset weights sum to 1
    
    #VaR constraints
    for aa in range(n_alpha): #for all VaR constraints
        n_activeCon = np.ceil(n*(1-alpha[aa])) #number of constraints that need to be active at solution
        
        v = [] #indices of violation samples (samples for which a feasible w exists that would violate the VaR constraint)
        for i in range(n):
            if any(X[i,:] < VaR[aa]): #else, no weights w lead to a return of sample i to be less than the VaR
                v.append(i)
        n_v = len(v) 
        V[aa] = v #useful for visualising the solution

        z = [m.add_var(name=f"z_{aa}_{vv}",var_type=BINARY) for vv in range(n_v) ] #selector variable for active constraints
        m += xsum(m.var_by_name(f'z_{aa}_{vv}') for vv in range(n_v)) == max(0,n_activeCon - (n-n_v)) #n-n_v constraints always satisfied
        for vv in range(n_v):
            m += xsum(w[dd]*X[v[vv],dd] for dd in range(d)) >= (VaR[aa] - (1-m.var_by_name(f'z_{aa}_{vv}'))*M) #linearized VaR constraint using bigg M notation
    
    #weight constraints
    if type(max_weight) != list and max_weight != 1: 
        for dd in range(d):
            m += w[dd] <= max_weight
    else:
        for dd in range(d):
            m += w[dd] <= max_weight[dd]

    #obtain model summary
    m.write('model.lp')
    m.read('model.lp')
    print('The model has {} vars, {} constraints and {} nzs'.format(m.num_cols, m.num_rows, m.num_nz))

    # optimizing
    status = m.optimize(max_seconds = max_s)
    if status != OptimizationStatus.OPTIMAL:
        print(np.round(alpha,3), np.round(VaR,3), status) #if solution not optimal, print details
    return m,V

# %% [markdown]
# ## 4. Numerical Example
#
# We now consider a simple 2-dimensional example ($d=2$), where the two assets are the S&P 500 index ("gspc") and the gold price ("gold"). For the purpose of this simple example we ignore any other costs related to the investment or its liquidation (e.g. taxes). We use the following helper function to
# * extract the data from ".csv"-files,
# * fill in missing values for days without trade (e.g. weekends),
# * to select the common period for all assets
# * and to store the results in a pandas data frame.

# %%
def loadData(files, days):
    """
    Reads csv "files", fills in missing dates and close prices, computes annualized returns over the number of "days" and returns a pandas 
    data frame.
    """
    years=1#days/365 #used to compute annualized returns
    dataFrames_in = []
    start_dates = [] 
    end_dates =[] #used to find greatest common trade period
    
    for file in files:
        df_in = pd.read_csv('C:/Users/worc3920/Documents/GitHub/EmpiricalPortfolio/data/'+file+'.csv', usecols=["Date","Close"]) #file path may depend on your project
        df_in = df_in.rename(columns={"Close": "Close_" + file})
        df_in["Date"]=pd.to_datetime(df_in["Date"], infer_datetime_format=True)
        dataFrames_in.append(df_in)
        start_dates.append(df_in.loc[0,"Date"])
        end_dates.append(df_in.loc[df_in.index[-1],"Date"])
    
    df_start = max(start_dates) #select latest common start date
    df_end = min(end_dates) #select earliest common end date, hence data available for all selected dates and assets
    df = pd.DataFrame()
    df["Date"] = pd.date_range(start=df_start, end=df_end)

    for i in range(len(files)):
        df = df.merge(dataFrames_in[i], on='Date', how='inner') #combine data frames, "inner" to avoid nan values
    
    df = df.dropna()
    df = df.reset_index(drop=True)
    for file in files:
        #Ensure no NaN values at the beginning of the data set
        #j=0
        #while True:
        #    if np.isnan(df.loc[j,"Close_" + file]):
        #        j += 1
        #    else:
        #        df.loc[0:j-1,"Close_" + file] = df.loc[j,"Close_" + file]
        #        break
        #Replace NaN values by previous (valid) value
        #for i in range(0,len(df)):
        #    if np.isnan(df.loc[i,"Close_" + file]):
        #        df.loc[i, "Close_" + file] = df.loc[i-1, "Close_"+file]
        
        #Compute return, assuming that negative final values will be replaced by 0
        for i in range(len(df)-days):
            #df.loc[i, "Return_" + file] = np.log((np.max([0,df.loc[i+days, "Close_"+file]])/df.loc[i, "Close_"+file])**(1/years)) #log annual return
            df.loc[i, "Return_" + file] = np.log(np.max([0,df.loc[i+days, "Close_"+file]])/df.loc[i, "Close_"+file]) #log daily return
    #drop last days entries, for which no return could be computed
    return df.drop(columns=["Close_" + file for file in files]).iloc[:-days-1]

# %% [markdown]
# Let us begin by loading all required packages and obtaining the data using the above helper function:

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.colors as colors
import pandas as pd
import datetime
import warnings
from mip import *
import time

#read data and show summary
#files = ["gspc","gold","n225","hsi","oil"]
files = ["gspc","gold","hsi"]
days=1###253#365 #a year without weekends and holidays
df = loadData(files, days)
#df = df.dropna()
fileR = ["Return_" + file for file in files]
X = df[fileR].to_numpy()

# %%
df["equal_split"]=(df[fileR].sum(axis=1))/len(files)
print(np.round(df.describe(),2))

np.isnan(df).sum()
df["Date"].describe(datetime_is_numeric=True)
# Out:
#        Return_gspc  Return_hsi  equal_split
# count      7950.00     7950.00      7950.00
# mean          0.08        0.07         0.07
# std           0.16        0.25         0.18
# min          -0.72       -0.94        -0.83
# 25%           0.03       -0.08        -0.02
# 50%           0.10        0.10         0.11
# 75%           0.18        0.23         0.18
# max           0.55        0.85         0.58
# count                             7950
# mean     2003-06-16 22:13:40.528301952
# min                1986-12-31 00:00:00
# 25%                1995-03-10 18:00:00
# 50%                2003-06-14 12:00:00
# 75%                2011-09-14 18:00:00
# max                2019-12-31 00:00:00
# Name: Date, dtype: object

# %%
percentiles = [0.001,0.01]#,0.05]
n_df = len(df)
myVaR = np.sort(df["equal_split"].to_numpy())[[int(np.round(n_df*percentiles[i])) for i in range(len(percentiles))]]
print(np.array(percentiles)*100) #percentiles in percent
print(np.round(myVaR*100,2)) #VaR in percent
# Out:
# [0.1 1. ]
# [-7.28 -2.96]

# %%
df[fileR].corr()
# Out:
#              Return_gspc  Return_hsi
# Return_gspc     1.000000    0.200313
# Return_hsi      0.200313    1.000000

# %%
epsilon=10**(-3)
fileR_e = fileR.copy()
fileR_e.append("equal_split")
fig, ax = plt.subplots(figsize=(12, 8))
#ax.plot(df["Date"], np.log(df["Return_gspc"]+1+epsilon), linewidth=0.1)
ax.plot(df["Date"], np.exp(df[fileR])-1, linewidth=0.5, alpha=1)
ax.legend(fileR_e);
#ax.set_ylim((-10,10))
#ax.set_xlim((0,1000))

# %% [markdown]
# Notice that an equal allocation to both assets would result in a mean between the means of the individual assets, but the standard error (std) is smaller.

# %%
X = df[fileR].to_numpy()
X00 = X[[X[i,0]!=0 and X[i,1] !=0 for i in range(len(X))],:]
fig, ax = plt.subplots(figsize=(8, 8))
epsilon=10**(-3)
plt.scatter(X[::days,0],X[::days,1],s=1)
ax.legend(fileR_e);
#ax.set_ylim((-0.05,0.05))
#ax.set_xlim((-0.05,0.05))
plt.gca().set_aspect('equal', adjustable='box')

# %%
from scipy.optimize import minimize
import numpy as np
from scipy.special import gamma


class mgarch:
    
    def __init__(self, dist = 'norm'):
        if dist == 'norm' or dist == 't':
            self.dist = dist
        else: 
            print("Takes pdf name as param: 'norm' or 't'.")
            
    def garch_fit(self, returns):
        res = minimize( self.garch_loglike, (0.01, 0.01, 0.94), args = returns,
              bounds = ((1e-6, 1), (1e-6, 1), (1e-6, 1)))
        return res.x

    def garch_loglike(self, params, returns):
        T = len(returns)
        var_t = self.garch_var(params, returns)
        LogL = np.sum(-np.log(2*np.pi*var_t)) - np.sum( (returns.A1**2)/(2*var_t))
        return -LogL

    def garch_var(self, params, returns):
        T = len(returns)
        omega = params[0]
        alpha = params[1]
        beta = params[2]
        var_t = np.zeros(T)     
        for i in range(T):
            if i==0:
                var_t[i] = returns[i]**2
            else: 
                var_t[i] = omega + alpha*(returns[i-1]**2) + beta*var_t[i-1]
        return var_t        
        
    def mgarch_loglike(self, params, D_t):
        # No of assets
        a = params[0]
        b = params[1]
        Q_bar = np.cov(self.rt.reshape(self.N, self.T))

        Q_t = np.zeros((self.T,self.N,self.N))
        R_t = np.zeros((self.T,self.N,self.N))
        H_t = np.zeros((self.T,self.N,self.N))
        
        Q_t[0] = np.matmul(self.rt[0].T/2, self.rt[0]/2)

        loglike = 0
        for i in range(1,self.T):
            dts = np.diag(D_t[i])
            dtinv = np.linalg.inv(dts)
            et = dtinv*self.rt[i].T
            Q_t[i] = (1-a-b)*Q_bar + a*(et*et.T) + b*Q_t[i-1]
            qts = np.linalg.inv(np.sqrt(np.diag(np.diag(Q_t[i]))))

            R_t[i] = np.matmul(qts, np.matmul(Q_t[i], qts))


            H_t[i] = np.matmul(dts, np.matmul(R_t[i], dts))   

            loglike = loglike + self.N*np.log(2*np.pi) + \
                      2*np.log(D_t[i].sum()) + \
                      np.log(np.linalg.det(R_t[i])) + \
                      np.matmul(self.rt[i], (np.matmul( np.linalg.inv(H_t[i]), self.rt[i].T)))


        return float(loglike)

    
    def mgarch_logliket(self, params, D_t):
        # No of assets
        a = params[0]
        b = params[1]
        dof = params[2]
        Q_bar = np.cov(self.rt.reshape(self.N, self.T))

        Q_t = np.zeros((self.T,self.N,self.N))
        R_t = np.zeros((self.T,self.N,self.N))
        H_t = np.zeros((self.T,self.N,self.N))
        
        Q_t[0] = np.matmul(self.rt[0].T/2, self.rt[0]/2)

        loglike = 0
        for i in range(1,self.T):
            dts = np.diag(D_t[i])
            dtinv = np.linalg.inv(dts)
            et = dtinv*self.rt[i].T
            Q_t[i] = (1-a-b)*Q_bar + a*(et*et.T) + b*Q_t[i-1]
            qts = np.linalg.inv(np.sqrt(np.diag(np.diag(Q_t[i]))))

            R_t[i] = np.matmul(qts, np.matmul(Q_t[i], qts))


            H_t[i] = np.matmul(dts, np.matmul(R_t[i], dts))   

            loglike = loglike + np.log( gamma((self.N+dof)/2.)) - np.log(gamma(dof/2)) \
                      -(self.N/2.)*np.log(np.pi*(dof - 2)) - np.log(np.linalg.det(H_t[i])) \
- ((dof+ self.N)*( ((np.matmul(self.rt[i], (np.matmul( np.linalg.inv(H_t[i]), self.rt[i].T))))/(dof - 2.)) + 1)/2.)

        return -loglike
    
    
    def predict(self, new_rt, ndays = 1, justH=True):
        if 'a' in dir(self):
            self.rt = np.matrix(new_rt)
            self.T, self.N = self.rt.shape
            Q_bar = np.cov(self.rt.reshape(self.N, self.T))

            Q_t = np.zeros((self.T,self.N,self.N))
            R_t = np.zeros((self.T,self.N,self.N)) #matrix of conditional correlations
            H_t = np.zeros((self.T,self.N,self.N)) #conditional covariance matrix

            Q_t[0] = np.matmul(self.rt[0].T/2, self.rt[0]/2)

            loglike = 0
            if len(self.D_t) == self.T:
                D_t = np.zeros((self.T, self.N))
                var = np.zeros((self.T, self.N))
                for i in range(self.N):
                    params = self.params[i]
                    var[:,i] = self.garch_var(params, self.rt[:,i])
                    D_t[:,i] = np.sqrt(var[:,i])
                self.D_t = D_t
                self.var = var
                
                for i in range(1,self.T):
                    dts = np.diag(self.D_t[i])  #diagonal matrix of conditional variances
                    dtinv = np.linalg.inv(dts)  #its inverse
                    et = dtinv*self.rt[i].T     #conditional errors?
                    Q_t[i] = (1-self.a-self.b)*Q_bar + self.a*(et*et.T) + self.b*Q_t[i-1]
                    qts = np.linalg.inv(np.sqrt(np.diag(np.diag(Q_t[i]))))
                    R_t[i] = np.matmul(qts, np.matmul(Q_t[i], qts))
                    H_t[i] = np.matmul(dts, np.matmul(R_t[i], dts))
                self.Q_t=Q_t
                self.R_t=R_t
                self.H_t=H_t

            elif len(self.D_t) == self.T - 1:
                D_t = np.r_[self.D_t, np.zeros((1,self.N))]
                var = np.r_[self.var, np.zeros((1,self.N))]
                for i in range(self.N):
                    params = self.params[i]
                    var[-1,i] = params[0] + params[1]*(self.rt[-2,i]**2) + params[2]*var[-2,i]
                    D_t[-1,i] = np.sqrt(var[-1,i])
                self.D_t = D_t
                self.var = var
                
                #create storage
                Q_t[:-1,:]=self.Q_t
                R_t[:-1,:]=self.R_t
                H_t[:-1,:]=self.H_t
                
                #add last entry
                i=self.T-1 #index is one less than number of time steps
                dts = np.diag(self.D_t[i])  #diagonal matrix of conditional variances
                dtinv = np.linalg.inv(dts)  #its inverse
                et = dtinv*self.rt[i].T     #conditional errors?
                Q_t[i] = (1-self.a-self.b)*Q_bar + self.a*(et*et.T) + self.b*Q_t[i-1]
                qts = np.linalg.inv(np.sqrt(np.diag(np.diag(Q_t[i]))))
                R_t[i] = np.matmul(qts, np.matmul(Q_t[i], qts))
                H_t[i] = np.matmul(dts, np.matmul(R_t[i], dts))
                self.Q_t=Q_t
                self.R_t=R_t
                self.H_t=H_t
                
            elif len(self.D_t) < self.T -1:
                print("Something has gone wrong...")
                #print(len(self.D_t))
                #print(self.T)
                #print(self.H_t.shape)
            #for i in range(1,self.T):
            #    dts = np.diag(self.D_t[i])  #diagonal matrix of conditional variances
            #    dtinv = np.linalg.inv(dts)  #its inverse
            #    et = dtinv*self.rt[i].T     #conditional errors?
            #    Q_t[i] = (1-self.a-self.b)*Q_bar + self.a*(et*et.T) + self.b*Q_t[i-1]
            #    qts = np.linalg.inv(np.sqrt(np.diag(np.diag(Q_t[i]))))
            #
            #    R_t[i] = np.matmul(qts, np.matmul(Q_t[i], qts))
            #    H_t[i] = np.matmul(dts, np.matmul(R_t[i], dts))  

            ##########additional attributes
            if justH == True:
                return H_t[-1]
            if self.dist == 'norm':
                return {'dist': self.dist, 'cov': H_t[-1]*np.sqrt(ndays)}
            elif self.dist == 't':
                return {'dist': self.dist, 'dof': self.dof, 'cov': H_t[-1]*np.sqrt(ndays)}
            
        else:
            print('Model not fit')
            
            
    def fit(self, returns):
        self.rt = np.matrix(returns)
        
        self.T = self.rt.shape[0]
        self.N = self.rt.shape[1]
        
        if self.N == 1 or self.T == 1:
            return 'Required: 2d-array with columns > 2' 
        self.mean = self.rt.mean(axis = 0)
        self.rt = self.rt - self.mean
        
        D_t = np.zeros((self.T, self.N))
        params=[]
        for i in range(self.N):
            params.append(self.garch_fit(self.rt[:,i]))
            D_t[:,i] = np.sqrt(self.garch_var(params[-1], self.rt[:,i]))
        self.D_t = D_t
        self.params = params
        
        if self.dist == 'norm':
            res = minimize(self.mgarch_loglike, (0.01, 0.94), 
                           args = D_t, bounds = ((1e-6, 1), (1e-6, 1)))#,options = {'maxiter':10000000, 'disp':True})
            self.a = res.x[0]
            self.b = res.x[1]
            
            return {'mu': self.mean, 'alpha': self.a, 'beta': self.b} 
        elif self.dist == 't':
            res = minimize(self.mgarch_logliket, (0.01, 0.94, 3), args = D_t,
            bounds = ((1e-6, 1), (1e-6, 1), (3, None)), 
            #options = {'maxiter':10000000, 'disp':True},
            )
            self.a = res.x[0]
            self.b = res.x[1]
            self.dof = res.x[2]
            return {'mu': self.mean, 'alpha': self.a, 'beta': self.b, 'dof': self.dof}

# %%
import copy
def sample_pred(rt, rand_z, pred_horizon, res_varma, dcc_in):
    rt_w_pred = rt.copy()
    dcc = copy.copy(dcc_in)
    for ttp in range(pred_horizon):
        #predict conditional covariance matrix
        H_t1 = dcc.predict(justH = True, new_rt = rt_w_pred)

        #predict new data point
        r_t1 = res_varma.predict(start = dcc.T + 1 + ttp, end = dcc.T + 1 + ttp) + np.array(dcc.mean).reshape(dcc.N,) + cholesky(H_t1) @ rand_z[ttp,:]

        #extend VARMA model
        rt_w_pred = np.r_[rt_w_pred, r_t1]
    
    #return predicted returns
    return rt_w_pred[-pred_horizon:,:]

# %%
from scipy.optimize import minimize
import statsmodels.api as sm

print(days)
days=1
X_exp = X[::days,:] #experiment data (every 30 days)
#X_exp[:,[0,1]] = X_exp[:,[1,0]]
pred_horizon = 253 #predict 1 year ahead, excluding week ends and bank holidays


#fit VARMA model
myp=1
myq=1
mod = sm.tsa.VARMAX(X_exp, order=(myp,myq))
res_varma = mod.fit(maxiter=100, disp=True)
print("VARMA model fitted.")

rt_w_pred = res_varma.resid #returns with predictions holder, given by the residuals of the VARMA model
#fit GARCH model with available data
dcc = mgarch('norm')
res_dcc = dcc.fit(rt_w_pred)
print("DCC-GARCH model fitted.")

#obtain standardized residual errors
dcc.predict(new_rt = rt_w_pred) #to obtain H_t
H_t_half_inv = np.zeros((dcc.T,dcc.N,dcc.N))
for tt in range(1,dcc.T):
    H_t_half_inv[tt,:,:] = inv(cholesky(dcc.H_t[tt,:,:]))

z = np.zeros((dcc.T,dcc.N))
for tt in range(dcc.T):
    z[tt,:] = H_t_half_inv[tt,:,:] @ (rt_w_pred[tt,:]-np.array(dcc.mean).reshape(dcc.N,))

print("z obtained.")

n_samples = 1000
predictions = np.zeros((pred_horizon, dcc.N, n_samples)) #pred horizon x assets x samples
for nn in range(n_samples):
    print(f"Predicting sample {nn+1} out of {n_samples}.")
    
    #random residual choices
    random_indices = np.random.choice(a=len(z), size=pred_horizon, replace=True)
    rand_z = z[random_indices,:]
    
    #bootstrapped prediction
    predictions[:,:,nn] = sample_pred(rt_w_pred, rand_z, pred_horizon, res_varma, dcc)

print("Done.")
# Out:
# 1
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# VARMA model fitted.
# DCC-GARCH model fitted.
# z obtained.
# Predicting sample 1 out of 1000.
# Predicting sample 2 out of 1000.
# Predicting sample 3 out of 1000.
# Predicting sample 4 out of 1000.
# Predicting sample 5 out of 1000.
# Predicting sample 6 out of 1000.
# Predicting sample 7 out of 1000.
# Predicting sample 8 out of 1000.
# Predicting sample 9 out of 1000.
# Predicting sample 10 out of 1000.
# Predicting sample 11 out of 1000.
# Predicting sample 12 out of 1000.
# Predicting sample 13 out of 1000.
# Predicting sample 14 out of 1000.
# Predicting sample 15 out of 1000.
# Predicting sample 16 out of 1000.
# Predicting sample 17 out of 1000.
# Predicting sample 18 out of 1000.
# Predicting sample 19 out of 1000.
# Predicting sample 20 out of 1000.
# Predicting sample 21 out of 1000.
# Predicting sample 22 out of 1000.
# Predicting sample 23 out of 1000.
# Predicting sample 24 out of 1000.
# Predicting sample 25 out of 1000.
# Predicting sample 26 out of 1000.
# Predicting sample 27 out of 1000.
# Predicting sample 28 out of 1000.
# Predicting sample 29 out of 1000.
# Predicting sample 30 out of 1000.
# Predicting sample 31 out of 1000.
# Predicting sample 32 out of 1000.
# Predicting sample 33 out of 1000.
# Predicting sample 34 out of 1000.
# Predicting sample 35 out of 1000.
# Predicting sample 36 out of 1000.
# Predicting sample 37 out of 1000.
# Predicting sample 38 out of 1000.
# Predicting sample 39 out of 1000.
# Predicting sample 40 out of 1000.
# Predicting sample 41 out of 1000.
# Predicting sample 42 out of 1000.
# Predicting sample 43 out of 1000.
# Predicting sample 44 out of 1000.
# Predicting sample 45 out of 1000.
# Predicting sample 46 out of 1000.
# Predicting sample 47 out of 1000.
# Predicting sample 48 out of 1000.
# Predicting sample 49 out of 1000.
# Predicting sample 50 out of 1000.
# Predicting sample 51 out of 1000.
# Predicting sample 52 out of 1000.
# Predicting sample 53 out of 1000.
# Predicting sample 54 out of 1000.
# Predicting sample 55 out of 1000.
# Predicting sample 56 out of 1000.
# Predicting sample 57 out of 1000.
# Predicting sample 58 out of 1000.
# Predicting sample 59 out of 1000.
# Predicting sample 60 out of 1000.
# Predicting sample 61 out of 1000.
# Predicting sample 62 out of 1000.
# Predicting sample 63 out of 1000.
# Predicting sample 64 out of 1000.
# Predicting sample 65 out of 1000.
# Predicting sample 66 out of 1000.
# Predicting sample 67 out of 1000.
# Predicting sample 68 out of 1000.
# Predicting sample 69 out of 1000.
# Predicting sample 70 out of 1000.
# Predicting sample 71 out of 1000.
# Predicting sample 72 out of 1000.
# Predicting sample 73 out of 1000.
# Predicting sample 74 out of 1000.
# Predicting sample 75 out of 1000.
# Predicting sample 76 out of 1000.
# Predicting sample 77 out of 1000.
# Predicting sample 78 out of 1000.
# Predicting sample 79 out of 1000.
# Predicting sample 80 out of 1000.
# Predicting sample 81 out of 1000.
# Predicting sample 82 out of 1000.
# Predicting sample 83 out of 1000.
# Predicting sample 84 out of 1000.
# Predicting sample 85 out of 1000.
# Predicting sample 86 out of 1000.
# Predicting sample 87 out of 1000.
# Predicting sample 88 out of 1000.
# Predicting sample 89 out of 1000.
# Predicting sample 90 out of 1000.
# Predicting sample 91 out of 1000.
# Predicting sample 92 out of 1000.
# Predicting sample 93 out of 1000.
# Predicting sample 94 out of 1000.
# Predicting sample 95 out of 1000.
# Predicting sample 96 out of 1000.
# Predicting sample 97 out of 1000.
# Predicting sample 98 out of 1000.
# Predicting sample 99 out of 1000.
# Predicting sample 100 out of 1000.
# Predicting sample 101 out of 1000.
# Predicting sample 102 out of 1000.
# Predicting sample 103 out of 1000.
# Predicting sample 104 out of 1000.
# Predicting sample 105 out of 1000.
# Predicting sample 106 out of 1000.
# Predicting sample 107 out of 1000.
# Predicting sample 108 out of 1000.
# Predicting sample 109 out of 1000.
# Predicting sample 110 out of 1000.
# Predicting sample 111 out of 1000.
# Predicting sample 112 out of 1000.
# Predicting sample 113 out of 1000.
# Predicting sample 114 out of 1000.
# Predicting sample 115 out of 1000.
# Predicting sample 116 out of 1000.
# Predicting sample 117 out of 1000.
# Predicting sample 118 out of 1000.
# Predicting sample 119 out of 1000.
# Predicting sample 120 out of 1000.
# Predicting sample 121 out of 1000.
# Predicting sample 122 out of 1000.
# Predicting sample 123 out of 1000.
# Predicting sample 124 out of 1000.
# Predicting sample 125 out of 1000.
# Predicting sample 126 out of 1000.
# Predicting sample 127 out of 1000.
# Predicting sample 128 out of 1000.
# Predicting sample 129 out of 1000.
# Predicting sample 130 out of 1000.
# Predicting sample 131 out of 1000.
# Predicting sample 132 out of 1000.
# Predicting sample 133 out of 1000.
# Predicting sample 134 out of 1000.
# Predicting sample 135 out of 1000.
# Predicting sample 136 out of 1000.
# Predicting sample 137 out of 1000.
# Predicting sample 138 out of 1000.
# Predicting sample 139 out of 1000.
# Predicting sample 140 out of 1000.
# Predicting sample 141 out of 1000.
# Predicting sample 142 out of 1000.
# Predicting sample 143 out of 1000.
# Predicting sample 144 out of 1000.
# Predicting sample 145 out of 1000.
# Predicting sample 146 out of 1000.
# Predicting sample 147 out of 1000.
# Predicting sample 148 out of 1000.
# Predicting sample 149 out of 1000.
# Predicting sample 150 out of 1000.
# Predicting sample 151 out of 1000.
# Predicting sample 152 out of 1000.
# Predicting sample 153 out of 1000.
# Predicting sample 154 out of 1000.
# Predicting sample 155 out of 1000.
# Predicting sample 156 out of 1000.
# Predicting sample 157 out of 1000.
# Predicting sample 158 out of 1000.
# Predicting sample 159 out of 1000.
# Predicting sample 160 out of 1000.
# Predicting sample 161 out of 1000.
# Predicting sample 162 out of 1000.
# Predicting sample 163 out of 1000.
# Predicting sample 164 out of 1000.
# Predicting sample 165 out of 1000.
# Predicting sample 166 out of 1000.
# Predicting sample 167 out of 1000.
# Predicting sample 168 out of 1000.
# Predicting sample 169 out of 1000.
# Predicting sample 170 out of 1000.
# Predicting sample 171 out of 1000.
# Predicting sample 172 out of 1000.
# Predicting sample 173 out of 1000.
# Predicting sample 174 out of 1000.
# Predicting sample 175 out of 1000.
# Predicting sample 176 out of 1000.
# Predicting sample 177 out of 1000.
# Predicting sample 178 out of 1000.
# Predicting sample 179 out of 1000.
# Predicting sample 180 out of 1000.
# Predicting sample 181 out of 1000.
# Predicting sample 182 out of 1000.
# Predicting sample 183 out of 1000.
# Predicting sample 184 out of 1000.
# Predicting sample 185 out of 1000.
# Predicting sample 186 out of 1000.
# Predicting sample 187 out of 1000.
# Predicting sample 188 out of 1000.
# Predicting sample 189 out of 1000.
# Predicting sample 190 out of 1000.
# Predicting sample 191 out of 1000.
# Predicting sample 192 out of 1000.
# Predicting sample 193 out of 1000.
# Predicting sample 194 out of 1000.
# Predicting sample 195 out of 1000.
# Predicting sample 196 out of 1000.
# Predicting sample 197 out of 1000.
# Predicting sample 198 out of 1000.
# Predicting sample 199 out of 1000.
# Predicting sample 200 out of 1000.
# Predicting sample 201 out of 1000.
# Predicting sample 202 out of 1000.
# Predicting sample 203 out of 1000.
# Predicting sample 204 out of 1000.
# Predicting sample 205 out of 1000.
# Predicting sample 206 out of 1000.
# Predicting sample 207 out of 1000.
# Predicting sample 208 out of 1000.
# Predicting sample 209 out of 1000.
# Predicting sample 210 out of 1000.
# Predicting sample 211 out of 1000.
# Predicting sample 212 out of 1000.
# Predicting sample 213 out of 1000.
# Predicting sample 214 out of 1000.
# Predicting sample 215 out of 1000.
# Predicting sample 216 out of 1000.
# Predicting sample 217 out of 1000.
# Predicting sample 218 out of 1000.
# Predicting sample 219 out of 1000.
# Predicting sample 220 out of 1000.
# Predicting sample 221 out of 1000.
# Predicting sample 222 out of 1000.
# Predicting sample 223 out of 1000.
# Predicting sample 224 out of 1000.
# Predicting sample 225 out of 1000.
# Predicting sample 226 out of 1000.
# Predicting sample 227 out of 1000.
# Predicting sample 228 out of 1000.
# Predicting sample 229 out of 1000.
# Predicting sample 230 out of 1000.
# Predicting sample 231 out of 1000.
# Predicting sample 232 out of 1000.
# Predicting sample 233 out of 1000.
# Predicting sample 234 out of 1000.
# Predicting sample 235 out of 1000.
# Predicting sample 236 out of 1000.
# Predicting sample 237 out of 1000.
# Predicting sample 238 out of 1000.
# Predicting sample 239 out of 1000.
# Predicting sample 240 out of 1000.
# Predicting sample 241 out of 1000.
# Predicting sample 242 out of 1000.
# Predicting sample 243 out of 1000.
# Predicting sample 244 out of 1000.
# Predicting sample 245 out of 1000.
# Predicting sample 246 out of 1000.
# Predicting sample 247 out of 1000.
# Predicting sample 248 out of 1000.
# Predicting sample 249 out of 1000.
# Predicting sample 250 out of 1000.
# Predicting sample 251 out of 1000.
# Predicting sample 252 out of 1000.
# Predicting sample 253 out of 1000.
# Predicting sample 254 out of 1000.
# Predicting sample 255 out of 1000.
# Predicting sample 256 out of 1000.
# Predicting sample 257 out of 1000.
# Predicting sample 258 out of 1000.
# Predicting sample 259 out of 1000.
# Predicting sample 260 out of 1000.
# Predicting sample 261 out of 1000.
# Predicting sample 262 out of 1000.
# Predicting sample 263 out of 1000.
# Predicting sample 264 out of 1000.
# Predicting sample 265 out of 1000.
# Predicting sample 266 out of 1000.
# Predicting sample 267 out of 1000.
# Predicting sample 268 out of 1000.
# Predicting sample 269 out of 1000.
# Predicting sample 270 out of 1000.
# Predicting sample 271 out of 1000.
# Predicting sample 272 out of 1000.
# Predicting sample 273 out of 1000.
# Predicting sample 274 out of 1000.
# Predicting sample 275 out of 1000.
# Predicting sample 276 out of 1000.
# Predicting sample 277 out of 1000.
# Predicting sample 278 out of 1000.
# Predicting sample 279 out of 1000.
# Predicting sample 280 out of 1000.
# Predicting sample 281 out of 1000.
# Predicting sample 282 out of 1000.
# Predicting sample 283 out of 1000.
# Predicting sample 284 out of 1000.
# Predicting sample 285 out of 1000.
# Predicting sample 286 out of 1000.
# Predicting sample 287 out of 1000.
# Predicting sample 288 out of 1000.
# Predicting sample 289 out of 1000.
# Predicting sample 290 out of 1000.
# Predicting sample 291 out of 1000.
# Predicting sample 292 out of 1000.
# Predicting sample 293 out of 1000.
# Predicting sample 294 out of 1000.
# Predicting sample 295 out of 1000.
# Predicting sample 296 out of 1000.
# Predicting sample 297 out of 1000.
# Predicting sample 298 out of 1000.
# Predicting sample 299 out of 1000.
# Predicting sample 300 out of 1000.
# Predicting sample 301 out of 1000.
# Predicting sample 302 out of 1000.
# Predicting sample 303 out of 1000.
# Predicting sample 304 out of 1000.
# Predicting sample 305 out of 1000.
# Predicting sample 306 out of 1000.
# Predicting sample 307 out of 1000.
# Predicting sample 308 out of 1000.
# Predicting sample 309 out of 1000.
# Predicting sample 310 out of 1000.
# Predicting sample 311 out of 1000.
# Predicting sample 312 out of 1000.
# Predicting sample 313 out of 1000.
# Predicting sample 314 out of 1000.
# Predicting sample 315 out of 1000.
# Predicting sample 316 out of 1000.
# Predicting sample 317 out of 1000.
# Predicting sample 318 out of 1000.
# Predicting sample 319 out of 1000.
# Predicting sample 320 out of 1000.
# Predicting sample 321 out of 1000.
# Predicting sample 322 out of 1000.
# Predicting sample 323 out of 1000.
# Predicting sample 324 out of 1000.
# Predicting sample 325 out of 1000.
# Predicting sample 326 out of 1000.
# Predicting sample 327 out of 1000.
# Predicting sample 328 out of 1000.
# Predicting sample 329 out of 1000.
# Predicting sample 330 out of 1000.
# Predicting sample 331 out of 1000.
# Predicting sample 332 out of 1000.
# Predicting sample 333 out of 1000.
# Predicting sample 334 out of 1000.
# Predicting sample 335 out of 1000.
# Predicting sample 336 out of 1000.
# Predicting sample 337 out of 1000.
# Predicting sample 338 out of 1000.
# Predicting sample 339 out of 1000.
# Predicting sample 340 out of 1000.
# Predicting sample 341 out of 1000.
# Predicting sample 342 out of 1000.
# Predicting sample 343 out of 1000.
# Predicting sample 344 out of 1000.
# Predicting sample 345 out of 1000.
# Predicting sample 346 out of 1000.
# Predicting sample 347 out of 1000.
# Predicting sample 348 out of 1000.
# Predicting sample 349 out of 1000.
# Predicting sample 350 out of 1000.
# Predicting sample 351 out of 1000.
# Predicting sample 352 out of 1000.
# Predicting sample 353 out of 1000.
# Predicting sample 354 out of 1000.
# Predicting sample 355 out of 1000.
# Predicting sample 356 out of 1000.
# Predicting sample 357 out of 1000.
# Predicting sample 358 out of 1000.
# Predicting sample 359 out of 1000.
# Predicting sample 360 out of 1000.
# Predicting sample 361 out of 1000.
# Predicting sample 362 out of 1000.
# Predicting sample 363 out of 1000.
# Predicting sample 364 out of 1000.
# Predicting sample 365 out of 1000.
# Predicting sample 366 out of 1000.
# Predicting sample 367 out of 1000.
# Predicting sample 368 out of 1000.
# Predicting sample 369 out of 1000.
# Predicting sample 370 out of 1000.
# Predicting sample 371 out of 1000.
# Predicting sample 372 out of 1000.
# Predicting sample 373 out of 1000.
# Predicting sample 374 out of 1000.
# Predicting sample 375 out of 1000.
# Predicting sample 376 out of 1000.
# Predicting sample 377 out of 1000.
# Predicting sample 378 out of 1000.
# Predicting sample 379 out of 1000.
# Predicting sample 380 out of 1000.
# Predicting sample 381 out of 1000.
# Predicting sample 382 out of 1000.
# Predicting sample 383 out of 1000.
# Predicting sample 384 out of 1000.
# Predicting sample 385 out of 1000.
# Predicting sample 386 out of 1000.
# Predicting sample 387 out of 1000.
# Predicting sample 388 out of 1000.
# Predicting sample 389 out of 1000.
# Predicting sample 390 out of 1000.
# Predicting sample 391 out of 1000.
# Predicting sample 392 out of 1000.
# Predicting sample 393 out of 1000.
# Predicting sample 394 out of 1000.
# Predicting sample 395 out of 1000.
# Predicting sample 396 out of 1000.
# Predicting sample 397 out of 1000.
# Predicting sample 398 out of 1000.
# Predicting sample 399 out of 1000.
# Predicting sample 400 out of 1000.
# Predicting sample 401 out of 1000.
# Predicting sample 402 out of 1000.
# Predicting sample 403 out of 1000.
# Predicting sample 404 out of 1000.
# Predicting sample 405 out of 1000.
# Predicting sample 406 out of 1000.
# Predicting sample 407 out of 1000.
# Predicting sample 408 out of 1000.
# Predicting sample 409 out of 1000.
# Predicting sample 410 out of 1000.
# Predicting sample 411 out of 1000.
# Predicting sample 412 out of 1000.
# Predicting sample 413 out of 1000.
# Predicting sample 414 out of 1000.
# Predicting sample 415 out of 1000.
# Predicting sample 416 out of 1000.
# Predicting sample 417 out of 1000.
# Predicting sample 418 out of 1000.
# Predicting sample 419 out of 1000.
# Predicting sample 420 out of 1000.
# Predicting sample 421 out of 1000.
# Predicting sample 422 out of 1000.
# Predicting sample 423 out of 1000.
# Predicting sample 424 out of 1000.
# Predicting sample 425 out of 1000.
# Predicting sample 426 out of 1000.
# Predicting sample 427 out of 1000.
# Predicting sample 428 out of 1000.
# Predicting sample 429 out of 1000.
# Predicting sample 430 out of 1000.
# Predicting sample 431 out of 1000.
# Predicting sample 432 out of 1000.
# Predicting sample 433 out of 1000.
# Predicting sample 434 out of 1000.
# Predicting sample 435 out of 1000.
# Predicting sample 436 out of 1000.
# Predicting sample 437 out of 1000.
# Predicting sample 438 out of 1000.
# Predicting sample 439 out of 1000.
# Predicting sample 440 out of 1000.
# Predicting sample 441 out of 1000.
# Predicting sample 442 out of 1000.
# Predicting sample 443 out of 1000.
# Predicting sample 444 out of 1000.
# Predicting sample 445 out of 1000.
# Predicting sample 446 out of 1000.
# Predicting sample 447 out of 1000.
# Predicting sample 448 out of 1000.
# Predicting sample 449 out of 1000.
# Predicting sample 450 out of 1000.
# Predicting sample 451 out of 1000.
# Predicting sample 452 out of 1000.
# Predicting sample 453 out of 1000.
# Predicting sample 454 out of 1000.
# Predicting sample 455 out of 1000.
# Predicting sample 456 out of 1000.
# Predicting sample 457 out of 1000.
# Predicting sample 458 out of 1000.
# Predicting sample 459 out of 1000.
# Predicting sample 460 out of 1000.
# Predicting sample 461 out of 1000.
# Predicting sample 462 out of 1000.
# Predicting sample 463 out of 1000.
# Predicting sample 464 out of 1000.
# Predicting sample 465 out of 1000.
# Predicting sample 466 out of 1000.
# Predicting sample 467 out of 1000.
# Predicting sample 468 out of 1000.
# Predicting sample 469 out of 1000.
# Predicting sample 470 out of 1000.
# Predicting sample 471 out of 1000.
# Predicting sample 472 out of 1000.
# Predicting sample 473 out of 1000.
# Predicting sample 474 out of 1000.
# Predicting sample 475 out of 1000.
# Predicting sample 476 out of 1000.
# Predicting sample 477 out of 1000.
# Predicting sample 478 out of 1000.
# Predicting sample 479 out of 1000.
# Predicting sample 480 out of 1000.
# Predicting sample 481 out of 1000.
# Predicting sample 482 out of 1000.
# Predicting sample 483 out of 1000.
# Predicting sample 484 out of 1000.
# Predicting sample 485 out of 1000.
# Predicting sample 486 out of 1000.
# Predicting sample 487 out of 1000.
# Predicting sample 488 out of 1000.
# Predicting sample 489 out of 1000.
# Predicting sample 490 out of 1000.
# Predicting sample 491 out of 1000.
# Predicting sample 492 out of 1000.
# Predicting sample 493 out of 1000.
# Predicting sample 494 out of 1000.
# Predicting sample 495 out of 1000.
# Predicting sample 496 out of 1000.
# Predicting sample 497 out of 1000.
# Predicting sample 498 out of 1000.
# Predicting sample 499 out of 1000.
# Predicting sample 500 out of 1000.
# Predicting sample 501 out of 1000.
# Predicting sample 502 out of 1000.
# Predicting sample 503 out of 1000.
# Predicting sample 504 out of 1000.
# Predicting sample 505 out of 1000.
# Predicting sample 506 out of 1000.
# Predicting sample 507 out of 1000.
# Predicting sample 508 out of 1000.
# Predicting sample 509 out of 1000.
# Predicting sample 510 out of 1000.
# Predicting sample 511 out of 1000.
# Predicting sample 512 out of 1000.
# Predicting sample 513 out of 1000.
# Predicting sample 514 out of 1000.
# Predicting sample 515 out of 1000.
# Predicting sample 516 out of 1000.
# Predicting sample 517 out of 1000.
# Predicting sample 518 out of 1000.
# Predicting sample 519 out of 1000.
# Predicting sample 520 out of 1000.
# Predicting sample 521 out of 1000.
# Predicting sample 522 out of 1000.
# Predicting sample 523 out of 1000.
# Predicting sample 524 out of 1000.
# Predicting sample 525 out of 1000.
# Predicting sample 526 out of 1000.
# Predicting sample 527 out of 1000.
# Predicting sample 528 out of 1000.
# Predicting sample 529 out of 1000.
# Predicting sample 530 out of 1000.
# Predicting sample 531 out of 1000.
# Predicting sample 532 out of 1000.
# Predicting sample 533 out of 1000.
# Predicting sample 534 out of 1000.
# Predicting sample 535 out of 1000.
# Predicting sample 536 out of 1000.
# Predicting sample 537 out of 1000.
# Predicting sample 538 out of 1000.
# Predicting sample 539 out of 1000.
# Predicting sample 540 out of 1000.
# Predicting sample 541 out of 1000.
# Predicting sample 542 out of 1000.
# Predicting sample 543 out of 1000.
# Predicting sample 544 out of 1000.
# Predicting sample 545 out of 1000.
# Predicting sample 546 out of 1000.
# Predicting sample 547 out of 1000.
# Predicting sample 548 out of 1000.
# Predicting sample 549 out of 1000.
# Predicting sample 550 out of 1000.
# Predicting sample 551 out of 1000.
# Predicting sample 552 out of 1000.
# Predicting sample 553 out of 1000.
# Predicting sample 554 out of 1000.
# Predicting sample 555 out of 1000.
# Predicting sample 556 out of 1000.
# Predicting sample 557 out of 1000.
# Predicting sample 558 out of 1000.
# Predicting sample 559 out of 1000.
# Predicting sample 560 out of 1000.
# Predicting sample 561 out of 1000.
# Predicting sample 562 out of 1000.
# Predicting sample 563 out of 1000.
# Predicting sample 564 out of 1000.
# Predicting sample 565 out of 1000.
# Predicting sample 566 out of 1000.
# Predicting sample 567 out of 1000.
# Predicting sample 568 out of 1000.
# Predicting sample 569 out of 1000.
# Predicting sample 570 out of 1000.
# Predicting sample 571 out of 1000.
# Predicting sample 572 out of 1000.
# Predicting sample 573 out of 1000.
# Predicting sample 574 out of 1000.
# Predicting sample 575 out of 1000.
# Predicting sample 576 out of 1000.
# Predicting sample 577 out of 1000.
# Predicting sample 578 out of 1000.
# Predicting sample 579 out of 1000.
# Predicting sample 580 out of 1000.
# Predicting sample 581 out of 1000.
# Predicting sample 582 out of 1000.
# Predicting sample 583 out of 1000.
# Predicting sample 584 out of 1000.
# Predicting sample 585 out of 1000.
# Predicting sample 586 out of 1000.
# Predicting sample 587 out of 1000.
# Predicting sample 588 out of 1000.
# Predicting sample 589 out of 1000.
# Predicting sample 590 out of 1000.
# Predicting sample 591 out of 1000.
# Predicting sample 592 out of 1000.
# Predicting sample 593 out of 1000.
# Predicting sample 594 out of 1000.
# Predicting sample 595 out of 1000.
# Predicting sample 596 out of 1000.
# Predicting sample 597 out of 1000.
# Predicting sample 598 out of 1000.
# Predicting sample 599 out of 1000.
# Predicting sample 600 out of 1000.
# Predicting sample 601 out of 1000.
# Predicting sample 602 out of 1000.
# Predicting sample 603 out of 1000.
# Predicting sample 604 out of 1000.
# Predicting sample 605 out of 1000.
# Predicting sample 606 out of 1000.
# Predicting sample 607 out of 1000.
# Predicting sample 608 out of 1000.
# Predicting sample 609 out of 1000.
# Predicting sample 610 out of 1000.
# Predicting sample 611 out of 1000.
# Predicting sample 612 out of 1000.
# Predicting sample 613 out of 1000.
# Predicting sample 614 out of 1000.
# Predicting sample 615 out of 1000.
# Predicting sample 616 out of 1000.
# Predicting sample 617 out of 1000.
# Predicting sample 618 out of 1000.
# Predicting sample 619 out of 1000.
# Predicting sample 620 out of 1000.
# Predicting sample 621 out of 1000.
# Predicting sample 622 out of 1000.
# Predicting sample 623 out of 1000.
# Predicting sample 624 out of 1000.
# Predicting sample 625 out of 1000.
# Predicting sample 626 out of 1000.
# Predicting sample 627 out of 1000.
# Predicting sample 628 out of 1000.
# Predicting sample 629 out of 1000.
# Predicting sample 630 out of 1000.
# Predicting sample 631 out of 1000.
# Predicting sample 632 out of 1000.
# Predicting sample 633 out of 1000.
# Predicting sample 634 out of 1000.
# Predicting sample 635 out of 1000.
# Predicting sample 636 out of 1000.
# Predicting sample 637 out of 1000.
# Predicting sample 638 out of 1000.
# Predicting sample 639 out of 1000.
# Predicting sample 640 out of 1000.
# Predicting sample 641 out of 1000.
# Predicting sample 642 out of 1000.
# Predicting sample 643 out of 1000.
# Predicting sample 644 out of 1000.
# Predicting sample 645 out of 1000.
# Predicting sample 646 out of 1000.
# Predicting sample 647 out of 1000.
# Predicting sample 648 out of 1000.
# Predicting sample 649 out of 1000.
# Predicting sample 650 out of 1000.
# Predicting sample 651 out of 1000.
# Predicting sample 652 out of 1000.
# Predicting sample 653 out of 1000.
# Predicting sample 654 out of 1000.
# Predicting sample 655 out of 1000.
# Predicting sample 656 out of 1000.
# Predicting sample 657 out of 1000.
# Predicting sample 658 out of 1000.
# Predicting sample 659 out of 1000.
# Predicting sample 660 out of 1000.
# Predicting sample 661 out of 1000.
# Predicting sample 662 out of 1000.
# Predicting sample 663 out of 1000.
# Predicting sample 664 out of 1000.
# Predicting sample 665 out of 1000.
# Predicting sample 666 out of 1000.
# Predicting sample 667 out of 1000.
# Predicting sample 668 out of 1000.
# Predicting sample 669 out of 1000.
# Predicting sample 670 out of 1000.
# Predicting sample 671 out of 1000.
# Predicting sample 672 out of 1000.
# Predicting sample 673 out of 1000.
# Predicting sample 674 out of 1000.
# Predicting sample 675 out of 1000.
# Predicting sample 676 out of 1000.
# Predicting sample 677 out of 1000.
# Predicting sample 678 out of 1000.
# Predicting sample 679 out of 1000.
# Predicting sample 680 out of 1000.
# Predicting sample 681 out of 1000.
# Predicting sample 682 out of 1000.
# Predicting sample 683 out of 1000.
# Predicting sample 684 out of 1000.
# Predicting sample 685 out of 1000.
# Predicting sample 686 out of 1000.
# Predicting sample 687 out of 1000.
# Predicting sample 688 out of 1000.
# Predicting sample 689 out of 1000.
# Predicting sample 690 out of 1000.
# Predicting sample 691 out of 1000.
# Predicting sample 692 out of 1000.
# Predicting sample 693 out of 1000.
# Predicting sample 694 out of 1000.
# Predicting sample 695 out of 1000.
# Predicting sample 696 out of 1000.
# Predicting sample 697 out of 1000.
# Predicting sample 698 out of 1000.
# Predicting sample 699 out of 1000.
# Predicting sample 700 out of 1000.
# Predicting sample 701 out of 1000.
# Predicting sample 702 out of 1000.
# Predicting sample 703 out of 1000.
# Predicting sample 704 out of 1000.
# Predicting sample 705 out of 1000.
# Predicting sample 706 out of 1000.
# Predicting sample 707 out of 1000.
# Predicting sample 708 out of 1000.
# Predicting sample 709 out of 1000.
# Predicting sample 710 out of 1000.
# Predicting sample 711 out of 1000.
# Predicting sample 712 out of 1000.
# Predicting sample 713 out of 1000.
# Predicting sample 714 out of 1000.
# Predicting sample 715 out of 1000.
# Predicting sample 716 out of 1000.
# Predicting sample 717 out of 1000.
# Predicting sample 718 out of 1000.
# Predicting sample 719 out of 1000.
# Predicting sample 720 out of 1000.
# Predicting sample 721 out of 1000.
# Predicting sample 722 out of 1000.
# Predicting sample 723 out of 1000.
# Predicting sample 724 out of 1000.
# Predicting sample 725 out of 1000.
# Predicting sample 726 out of 1000.
# Predicting sample 727 out of 1000.
# Predicting sample 728 out of 1000.
# Predicting sample 729 out of 1000.
# Predicting sample 730 out of 1000.
# Predicting sample 731 out of 1000.
# Predicting sample 732 out of 1000.
# Predicting sample 733 out of 1000.
# Predicting sample 734 out of 1000.
# Predicting sample 735 out of 1000.
# Predicting sample 736 out of 1000.
# Predicting sample 737 out of 1000.
# Predicting sample 738 out of 1000.
# Predicting sample 739 out of 1000.
# Predicting sample 740 out of 1000.
# Predicting sample 741 out of 1000.
# Predicting sample 742 out of 1000.
# Predicting sample 743 out of 1000.
# Predicting sample 744 out of 1000.
# Predicting sample 745 out of 1000.
# Predicting sample 746 out of 1000.
# Predicting sample 747 out of 1000.
# Predicting sample 748 out of 1000.
# Predicting sample 749 out of 1000.
# Predicting sample 750 out of 1000.
# Predicting sample 751 out of 1000.
# Predicting sample 752 out of 1000.
# Predicting sample 753 out of 1000.
# Predicting sample 754 out of 1000.
# Predicting sample 755 out of 1000.
# Predicting sample 756 out of 1000.
# Predicting sample 757 out of 1000.
# Predicting sample 758 out of 1000.
# Predicting sample 759 out of 1000.
# Predicting sample 760 out of 1000.
# Predicting sample 761 out of 1000.
# Predicting sample 762 out of 1000.
# Predicting sample 763 out of 1000.
# Predicting sample 764 out of 1000.
# Predicting sample 765 out of 1000.
# Predicting sample 766 out of 1000.
# Predicting sample 767 out of 1000.
# Predicting sample 768 out of 1000.
# Predicting sample 769 out of 1000.
# Predicting sample 770 out of 1000.
# Predicting sample 771 out of 1000.
# Predicting sample 772 out of 1000.
# Predicting sample 773 out of 1000.
# Predicting sample 774 out of 1000.
# Predicting sample 775 out of 1000.
# Predicting sample 776 out of 1000.
# Predicting sample 777 out of 1000.
# Predicting sample 778 out of 1000.
# Predicting sample 779 out of 1000.
# Predicting sample 780 out of 1000.
# Predicting sample 781 out of 1000.
# Predicting sample 782 out of 1000.
# Predicting sample 783 out of 1000.
# Predicting sample 784 out of 1000.
# Predicting sample 785 out of 1000.
# Predicting sample 786 out of 1000.
# Predicting sample 787 out of 1000.
# Predicting sample 788 out of 1000.
# Predicting sample 789 out of 1000.
# Predicting sample 790 out of 1000.
# Predicting sample 791 out of 1000.
# Predicting sample 792 out of 1000.
# Predicting sample 793 out of 1000.
# Predicting sample 794 out of 1000.
# Predicting sample 795 out of 1000.
# Predicting sample 796 out of 1000.
# Predicting sample 797 out of 1000.
# Predicting sample 798 out of 1000.
# Predicting sample 799 out of 1000.
# Predicting sample 800 out of 1000.
# Predicting sample 801 out of 1000.
# Predicting sample 802 out of 1000.
# Predicting sample 803 out of 1000.
# Predicting sample 804 out of 1000.
# Predicting sample 805 out of 1000.
# Predicting sample 806 out of 1000.
# Predicting sample 807 out of 1000.
# Predicting sample 808 out of 1000.
# Predicting sample 809 out of 1000.
# Predicting sample 810 out of 1000.
# Predicting sample 811 out of 1000.
# Predicting sample 812 out of 1000.
# Predicting sample 813 out of 1000.
# Predicting sample 814 out of 1000.
# Predicting sample 815 out of 1000.
# Predicting sample 816 out of 1000.
# Predicting sample 817 out of 1000.
# Predicting sample 818 out of 1000.
# Predicting sample 819 out of 1000.
# Predicting sample 820 out of 1000.
# Predicting sample 821 out of 1000.
# Predicting sample 822 out of 1000.
# Predicting sample 823 out of 1000.
# Predicting sample 824 out of 1000.
# Predicting sample 825 out of 1000.
# Predicting sample 826 out of 1000.
# Predicting sample 827 out of 1000.
# Predicting sample 828 out of 1000.
# Predicting sample 829 out of 1000.
# Predicting sample 830 out of 1000.
# Predicting sample 831 out of 1000.
# Predicting sample 832 out of 1000.
# Predicting sample 833 out of 1000.
# Predicting sample 834 out of 1000.
# Predicting sample 835 out of 1000.
# Predicting sample 836 out of 1000.
# Predicting sample 837 out of 1000.
# Predicting sample 838 out of 1000.
# Predicting sample 839 out of 1000.
# Predicting sample 840 out of 1000.
# Predicting sample 841 out of 1000.
# Predicting sample 842 out of 1000.
# Predicting sample 843 out of 1000.
# Predicting sample 844 out of 1000.
# Predicting sample 845 out of 1000.
# Predicting sample 846 out of 1000.
# Predicting sample 847 out of 1000.
# Predicting sample 848 out of 1000.
# Predicting sample 849 out of 1000.
# Predicting sample 850 out of 1000.
# Predicting sample 851 out of 1000.
# Predicting sample 852 out of 1000.
# Predicting sample 853 out of 1000.
# Predicting sample 854 out of 1000.
# Predicting sample 855 out of 1000.
# Predicting sample 856 out of 1000.
# Predicting sample 857 out of 1000.
# Predicting sample 858 out of 1000.
# Predicting sample 859 out of 1000.
# Predicting sample 860 out of 1000.
# Predicting sample 861 out of 1000.
# Predicting sample 862 out of 1000.
# Predicting sample 863 out of 1000.
# Predicting sample 864 out of 1000.
# Predicting sample 865 out of 1000.
# Predicting sample 866 out of 1000.
# Predicting sample 867 out of 1000.
# Predicting sample 868 out of 1000.
# Predicting sample 869 out of 1000.
# Predicting sample 870 out of 1000.
# Predicting sample 871 out of 1000.
# Predicting sample 872 out of 1000.
# Predicting sample 873 out of 1000.
# Predicting sample 874 out of 1000.
# Predicting sample 875 out of 1000.
# Predicting sample 876 out of 1000.
# Predicting sample 877 out of 1000.
# Predicting sample 878 out of 1000.
# Predicting sample 879 out of 1000.
# Predicting sample 880 out of 1000.
# Predicting sample 881 out of 1000.
# Predicting sample 882 out of 1000.
# Predicting sample 883 out of 1000.
# Predicting sample 884 out of 1000.
# Predicting sample 885 out of 1000.
# Predicting sample 886 out of 1000.
# Predicting sample 887 out of 1000.
# Predicting sample 888 out of 1000.
# Predicting sample 889 out of 1000.
# Predicting sample 890 out of 1000.
# Predicting sample 891 out of 1000.
# Predicting sample 892 out of 1000.
# Predicting sample 893 out of 1000.
# Predicting sample 894 out of 1000.
# Predicting sample 895 out of 1000.
# Predicting sample 896 out of 1000.
# Predicting sample 897 out of 1000.
# Predicting sample 898 out of 1000.
# Predicting sample 899 out of 1000.
# Predicting sample 900 out of 1000.
# Predicting sample 901 out of 1000.
# Predicting sample 902 out of 1000.
# Predicting sample 903 out of 1000.
# Predicting sample 904 out of 1000.
# Predicting sample 905 out of 1000.
# Predicting sample 906 out of 1000.
# Predicting sample 907 out of 1000.
# Predicting sample 908 out of 1000.
# Predicting sample 909 out of 1000.
# Predicting sample 910 out of 1000.
# Predicting sample 911 out of 1000.
# Predicting sample 912 out of 1000.
# Predicting sample 913 out of 1000.
# Predicting sample 914 out of 1000.
# Predicting sample 915 out of 1000.
# Predicting sample 916 out of 1000.
# Predicting sample 917 out of 1000.
# Predicting sample 918 out of 1000.
# Predicting sample 919 out of 1000.
# Predicting sample 920 out of 1000.
# Predicting sample 921 out of 1000.
# Predicting sample 922 out of 1000.
# Predicting sample 923 out of 1000.
# Predicting sample 924 out of 1000.
# Predicting sample 925 out of 1000.
# Predicting sample 926 out of 1000.
# Predicting sample 927 out of 1000.
# Predicting sample 928 out of 1000.
# Predicting sample 929 out of 1000.
# Predicting sample 930 out of 1000.
# Predicting sample 931 out of 1000.
# Predicting sample 932 out of 1000.
# Predicting sample 933 out of 1000.
# Predicting sample 934 out of 1000.
# Predicting sample 935 out of 1000.
# Predicting sample 936 out of 1000.
# Predicting sample 937 out of 1000.
# Predicting sample 938 out of 1000.
# Predicting sample 939 out of 1000.
# Predicting sample 940 out of 1000.
# Predicting sample 941 out of 1000.
# Predicting sample 942 out of 1000.
# Predicting sample 943 out of 1000.
# Predicting sample 944 out of 1000.
# Predicting sample 945 out of 1000.
# Predicting sample 946 out of 1000.
# Predicting sample 947 out of 1000.
# Predicting sample 948 out of 1000.
# Predicting sample 949 out of 1000.
# Predicting sample 950 out of 1000.
# Predicting sample 951 out of 1000.
# Predicting sample 952 out of 1000.
# Predicting sample 953 out of 1000.
# Predicting sample 954 out of 1000.
# Predicting sample 955 out of 1000.
# Predicting sample 956 out of 1000.
# Predicting sample 957 out of 1000.
# Predicting sample 958 out of 1000.
# Predicting sample 959 out of 1000.
# Predicting sample 960 out of 1000.
# Predicting sample 961 out of 1000.
# Predicting sample 962 out of 1000.
# Predicting sample 963 out of 1000.
# Predicting sample 964 out of 1000.
# Predicting sample 965 out of 1000.
# Predicting sample 966 out of 1000.
# Predicting sample 967 out of 1000.
# Predicting sample 968 out of 1000.
# Predicting sample 969 out of 1000.
# Predicting sample 970 out of 1000.
# Predicting sample 971 out of 1000.
# Predicting sample 972 out of 1000.
# Predicting sample 973 out of 1000.
# Predicting sample 974 out of 1000.
# Predicting sample 975 out of 1000.
# Predicting sample 976 out of 1000.
# Predicting sample 977 out of 1000.
# Predicting sample 978 out of 1000.
# Predicting sample 979 out of 1000.
# Predicting sample 980 out of 1000.
# Predicting sample 981 out of 1000.
# Predicting sample 982 out of 1000.
# Predicting sample 983 out of 1000.
# Predicting sample 984 out of 1000.
# Predicting sample 985 out of 1000.
# Predicting sample 986 out of 1000.
# Predicting sample 987 out of 1000.
# Predicting sample 988 out of 1000.
# Predicting sample 989 out of 1000.
# Predicting sample 990 out of 1000.
# Predicting sample 991 out of 1000.
# Predicting sample 992 out of 1000.
# Predicting sample 993 out of 1000.
# Predicting sample 994 out of 1000.
# Predicting sample 995 out of 1000.
# Predicting sample 996 out of 1000.
# Predicting sample 997 out of 1000.
# Predicting sample 998 out of 1000.
# Predicting sample 999 out of 1000.
# Predicting sample 1000 out of 1000.
# Done.

# %%
#plt.scatter(x=X_exp[:,0],y=X_exp[:,1])
#plt.scatter(x=predictions[-1,0,:],y=predictions[-1,1,:]);
print(np.max(np.abs(res_varma.resid)))
print(np.max(np.abs(z)))
print(len(z))
plt.plot(z)
# Out:
# 0.2853114333731643
# 44.54285125648686
# 8072
# [<matplotlib.lines.Line2D at 0x1c19220f6c8>,
#  <matplotlib.lines.Line2D at 0x1c1984dc9c8>,
#  <matplotlib.lines.Line2D at 0x1c1984c9288>]

# %%
asset=0

plt.plot(np.max(predictions[:,asset,:], axis=-1))
plt.plot(np.mean(predictions[:,asset,:],axis=-1)+1.96*np.std(predictions[:,asset,:],axis=-1))
plt.plot(np.mean(predictions[:,asset,:],axis=-1)-1.96*np.std(predictions[:,asset,:],axis=-1))
plt.plot(np.min(predictions[:,asset,:], axis=-1))
#plt.yscale('log')

# %%
#Predicted "un-logged" cumulative returns calculation:
#print(pred_horizon)
#print(np.sum(predictions,axis=0))
pred_returns = np.sum(predictions, axis = 0) # d x n_samples
#pred_returns = ((np.exp(pred_returns)**(1/pred_horizon)-1)).T #remove logs, convert to "standard" returns, transposed ##ASSUMING A HORIZON IN YEARS!!!!
pred_returns = (np.exp(pred_returns)-1).T
#plt.hist(pred_returns[:,1],bins=10);
#print(pred_returns)

getEmpiricalDensity(pred_returns, xlim=(-0.5,0.5))
df_pred = pd.DataFrame(pred_returns, columns=files)
df_pred.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5e59da016a08> in <module>
#       2 #print(pred_horizon)
#       3 #print(np.sum(predictions,axis=0))
# ----> 4 pred_returns = np.sum(predictions, axis = 0) # d x n_samples
#       5 #pred_returns = ((np.exp(pred_returns)**(1/pred_horizon)-1)).T #remove logs, convert to "standard" returns, transposed ##ASSUMING A HORIZON IN YEARS!!!!
#       6 pred_returns = (np.exp(pred_returns)-1).T
#
# NameError: name 'np' is not defined

# %%
fig, ax = plt.subplots(figsize=(8, 8))
plt.gca().set_aspect('equal', adjustable='box')
plt.scatter(x=pred_returns[:,0], y=pred_returns[:,1])
plt.scatter(x=pred_returns[:,0].mean(), y=pred_returns[:,1].mean(), c='r')
plt.grid(True)

# %%
#Select data and VaR constraints

alpha = [0.1]####percentiles#[0.001, 0.01, 0.02]#[0.001, 0.01, 0.1]#[0.001, 0.01, 0.10]
VaR = [-0.1] ####myVaR+0.001 #[0.03, 0.035, 0.04]#[0.02, 0.03, 0.04]#[-0.05, -0.02, 0.01]

skip = 1 #to speed up the solution process, we only select every "skip"-th row for this example
m,V = portfolioMILP(pred_returns, alpha, VaR, max_s = 10, max_weight=0.9) #run MILP for at most max_s seconds
#m,V = portfolioMILP(X[::skip,:], alpha, VaR, max_s = 10, max_weight=0.6) #run MILP for at most max_s seconds

if m.status == OptimizationStatus.OPTIMAL or m.status == OptimizationStatus.FEASIBLE:
    wStar = [m.vars[i].x for i in range(np.shape(pred_returns)[1])] #optimal weights
    print(m.status)
    print("The optimal asset allocation is "+str(np.round(wStar,2)))
    print("Portfolio return: "+str(np.round(sum(wStar*pred_returns.mean(axis=0))*100,2))+" %")
    print("Portfolio std: "+str(np.round(np.std([sum(wStar*pred_returns[i,:]) for i in range(pred_returns.shape[0])])*100,2))+" %")
# Out:
# Optimizing over 3 assets using 1000 samples
# The model has 405 vars, 407 constraints and 2016 nzs
# OptimizationStatus.OPTIMAL
# The optimal asset allocation is [0.9 0.  0.1]
# Portfolio return: 16.32 %
# Portfolio std: 87.24 %

# %%
ndays = 10 # volatility of nth day
cov_nextday = vol.predict(ndays)
print(cov_nextday["cov"])
# Out:
# [[9.12887388e-05 6.45674638e-05]
#  [6.45674638e-05 1.48238167e-04]]

# %%
from scipy.linalg import sqrtm, inv,cholesky
vol.predict()
print(cov_nextday["cov"])
print(res2)
print(vol.H_t.shape)
H_t_half_inv = np.zeros((vol.T,vol.N,vol.N))
for tt in range(1,vol.T):
    #print(vol.H_t[tt,:,:])
    H_t_half_inv[tt,:,:] = inv(cholesky(vol.H_t[tt,:,:]))
    

Y_garch = np.zeros((vol.T,vol.N))
for tt in range(vol.T):
    Y_garch[tt,:] = np.random.multivariate_normal(np.array(vol.mean).reshape(vol.N,), vol.H_t[tt,:,:])

asset=0
k=100
plt.figure()
plt.plot(rt[:k,asset]**2)

#z errors
z = np.zeros((vol.T,vol.N))
for tt in range(vol.T):
    z[tt,:] = H_t_half_inv[tt,:,:] @ (rt[tt,:]-np.array(vol.mean).reshape(vol.N,))
plt.figure()
plt.plot(z[:k,asset]**2)
# Out:
# [[9.12887388e-05 6.45674638e-05]
#  [6.45674638e-05 1.48238167e-04]]
# {'mu': matrix([[4.82561940e-06, 2.41371896e-06]]), 'alpha': 5.0901820562815056e-05, 'beta': 0.1691770567841763}
# (8202, 2, 2)

# %%
print(vol.H_t[5,:,:])
print(cholesky(vol.H_t[5,:,:]))
# Out:
# [[ 1.71676187e-04 -1.69024331e-05]
#  [-1.69024331e-05  8.34428142e-05]]
# [[ 0.01310253 -0.00129001]
#  [ 0.          0.00904316]]

# %%
asset=1
import scipy.stats as stats
fig, ax = plt.subplots(figsize=(12, 8))
ax.hist(X[X[:,asset]!=0,asset],density=True,bins=1000)
mu=X[X[:,asset]!=0,asset].mean()
sigma=X[X[:,asset]!=0,asset].std()
plotx = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)
ax.plot(plotx, stats.norm.pdf(plotx, mu, sigma))
print(mu,sigma)
print(len(X[X[:,asset]!=0,asset]))
# Out:
# 0.06970133654268666 0.24683402631836035
# 7950

# %%
asset=1
#x0 = X[X[:,asset]!=0,asset]
x0=X[:,asset]
groups=3
gr_size = int(np.floor(len(x0)/groups))

Mu = np.zeros(groups)
Sigma = np.zeros(groups)

xmin=-0.1
xmax=0.1

ymax=50

fig, ax_array = plt.subplots(groups)
for i, ax in enumerate(ax_array):
    x0i = x0[i*gr_size:(i+1)*gr_size]
    ax.hist(x0i, density=True,bins=np.linspace(xmin,xmax,100))
   
    ax.set_xlim((xmin,xmax))
    ax.set_ylim((0,ymax))
    Mu[i] = x0i.mean()
    Sigma[i] = x0i.std()

fig.subplots_adjust(hspace=1)
print(np.round(Mu,4))
print(np.round(Sigma,4))
# Out:
# [0.0005 0.0002 0.0001]
# [0.0188 0.0183 0.012 ]

# %%
#Select data and VaR constraints

alpha = [0.1]####percentiles#[0.001, 0.01, 0.02]#[0.001, 0.01, 0.1]#[0.001, 0.01, 0.10]
VaR = [-0.2] ####myVaR+0.001 #[0.03, 0.035, 0.04]#[0.02, 0.03, 0.04]#[-0.05, -0.02, 0.01]

skip = 1 #to speed up the solution process, we only select every "skip"-th row for this example
m,V = portfolioMILP(pred_returns, alpha, VaR, max_s = 10, max_weight=0.6) #run MILP for at most max_s seconds
#m,V = portfolioMILP(X[::skip,:], alpha, VaR, max_s = 10, max_weight=0.6) #run MILP for at most max_s seconds

if m.status == OptimizationStatus.OPTIMAL or m.status == OptimizationStatus.FEASIBLE:
    wStar = [m.vars[i].x for i in range(np.shape(pred_returns)[1])] #optimal weights
    print(m.status)
    print("The optimal asset allocation is "+str(np.round(wStar,2)))
    print("Portfolio return: "+str(np.round(sum(wStar*pred_returns.mean(axis=0))*100,2))+" %")
    print("Portfolio std: "+str(np.round(np.std([sum(wStar*pred_returns[i,:]) for i in range(pred_returns.shape[0])])*100,2))+" %")
# Out:
# Optimizing over 2 assets using 100 samples
# The model has 20 vars, 22 constraints and 76 nzs
# OptimizationStatus.OPTIMAL
# The optimal asset allocation is [0.4 0.6]
# Portfolio return: 10.97 %
# Portfolio std: 20.61 %

# %%
plt.plot(z)
# Out:
# [<matplotlib.lines.Line2D at 0x1c18e048308>,
#  <matplotlib.lines.Line2D at 0x1c1938c4e08>]

# %%
from statsmodels.tsa.stattools import acf, pacf
n_lags=10
print(days)
asset=0
#calling acf function from stattools
lag_acf = pacf(X[:,1], nlags=n_lags)#, fft=True)
#lag_acf = acf((Y_garch[:,asset]-res.resid[:,asset])**2, nlags=n_lags)#, fft=True)
#lag_acf = acf((res.resid[:,asset])**2, nlags=n_lags)#, fft=True)
#lag_acf = acf((z[:,asset])**2, nlags=n_lags)#, fft=True)
plt.figure(figsize=(12, 4))
#Plot ACF: 
plt.plot(lag_acf, marker="o",markersize=0.1)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(z)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(z)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
plt.xlabel('number of lags')
plt.ylabel('correlation')
plt.tight_layout()

axes = plt.gca()
axes.set_xlim(0,n_lags);
#axes.set_ylim(-0.5,0.5)

#pacf: 1,0
#acf: 0,1
# Out:
# 1

# %%
#checking stationarity
from statsmodels.tsa.vector_ar.vecm import coint_johansen
print(X.shape)
print(X[:,0].shape)
cj = coint_johansen(X[:,0],0,2)#stationary since smaller 

#    print(cj.max_eig_stat_crit_vals)
#    print(cj.max_eig_stat)
#    print()
#    print(cj.trace_stat_crit_vals)
#    print(cj.trace_stat)

#    print(cj.eig)


def joh_output(cj_res):
    output = pd.DataFrame([cj_res.lr2,cj_res.lr1],
                          index=['max_eig_stat',"trace_stat"])
    print(output.T,'\n')
    print("Critical values(90%, 95%, 99%) of max_eig_stat\n",cj_res.cvm,'\n')
    print("Critical values(90%, 95%, 99%) of trace_stat\n",cj_res.cvt,'\n')
joh_output(cj)
# Out:
# (8202, 2)
# (8202,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-300-e938f7b76b27> in <module>
#       3 print(X.shape)
#       4 print(X[:,0].shape)
# ----> 5 cj = coint_johansen(X[:,0],0,2)#stationary since smaller
#       6
#       7 #    print(cj.max_eig_stat_crit_vals)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\vector_ar\vecm.py in coint_johansen(endog, det_order, k_ar_diff)
#     574         warnings.warn("Critical values are only available for a det_order of "
#     575                       "-1, 0, or 1.", category=HypothesisTestWarning)
# --> 576     if endog.shape[1] > 12:  # todo: test with a time series of 13 variables
#     577         warnings.warn("Critical values are only available for time series "
#     578                       "with 12 variables at most.",
#
# IndexError: tuple index out of range

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")
        
adfuller_test(X[:,0])
adfuller_test(X[:,1])
adfuller_test(res.resid[:,0])
adfuller_test(res.resid[:,1])
# Out:
#     Augmented Dickey-Fuller Test on ""
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -22.6337
#  No. Lags Chosen       = 16
#  Critical value 1%     = -3.431
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#     Augmented Dickey-Fuller Test on ""
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -45.0338
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.431
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#     Augmented Dickey-Fuller Test on ""
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -90.5593
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.431
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#     Augmented Dickey-Fuller Test on ""
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -90.4605
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.431
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %%
plt.figure(figsize=(16, 7))
plt.plot(res.resid[:,0]**2,linewidth=1)
plt.plot(res.resid[:,1]**2,linewidth=1,alpha=0.5)
res_df = pd.DataFrame(res.resid)
res_df.describe()
# Out:
#                  0            1
# count  8202.000000  8202.000000
# mean      0.000008     0.000012
# std       0.011864     0.015176
# min      -0.233265    -0.277737
# 25%      -0.004800    -0.006969
# 50%       0.000400     0.000090
# 75%       0.005514     0.007303
# max       0.098950     0.139251

# %%
asset=0
x0=res.resid[:,asset]
groups=10
gr_size = int(np.floor(len(x0)/groups))

Mu = np.zeros(groups)
Sigma = np.zeros(groups)

xmin=-0.1
xmax=0.1

ymax=100

fig, ax_array = plt.subplots(groups)
for i, ax in enumerate(ax_array):
    x0i = x0[i*gr_size:(i+1)*gr_size]
    ax.hist(x0i, density=True,bins=np.linspace(xmin,xmax,100))
   
    ax.set_xlim((xmin,xmax))
    ax.set_ylim((0,ymax))
    Mu[i] = x0i.mean()
    Sigma[i] = x0i.std()

fig.subplots_adjust(hspace=1)
print(np.round(Mu,4))
print(np.round(Sigma,4))
# Out:
# [ 0.0002 -0.      0.0004  0.0004 -0.0008  0.0001 -0.0007  0.0002 -0.
#   0.0002]
# [0.0134 0.0082 0.0063 0.0129 0.0139 0.0068 0.0187 0.0105 0.0081 0.014 ]

# %%
plt.scatter(x=res.resid[:,0],y=res.resid[:,1], s=1)
res_df.corr()
# Out:
#           0         1
# 0  1.000000  0.243487
# 1  0.243487  1.000000

# %%
a=[1,2,3]
a[0:1]
# Out:
# [1]

# %%
#Univariate KS tests to check if distributions are identical

from scipy import stats
#data = np.random.normal(loc=0.0, scale=1.0, size=(8202,2))
data = z
#data = res.resid
#data= X
n,d = z.shape
print(n,d)
asset=0
groups_max = 10

ks_p = np.zeros((groups_max-1,groups_max-1)) #min is 2 groups, hence -1

for gg in range(groups_max-1): #gg is index, at least 2
    n_g = gg+2
    gr_size = int(np.floor(len(data)/n_g))
    for ii in range(gg+1):
        d0 = data[gr_size*ii:gr_size*(ii+1)+1,asset]
        d1 = data[gr_size*(ii+1):gr_size*(ii+2)+1,asset]
        _, ks_p[gg,ii] = stats.ks_2samp(d0,d1)

print((ks_p.round(4) >= 0.01).sum()/np.sum(np.arange(groups_max)))
# Out:
# 8202 2
# 0.37777777777777777

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
import statsmodels.api as sm

myp=1
myq=2
mod = sm.tsa.VARMAX(X, order=(myp,myq))
res_varma = mod.fit(maxiter=100, disp=True)
print(res_varma.summary())
# Out:
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:           ['y1', 'y2']   No. Observations:                 8202
# Model:                     VARMA(1,2)   Log Likelihood               47632.478
#                           + intercept   AIC                         -95230.955
# Date:                Mon, 22 Feb 2021   BIC                         -95111.749
# Time:                        09:36:51   HQIC                        -95190.204
# Sample:                             0
#                                - 8202
# Covariance Type:                  opg
# =====================================================================================
# Ljung-Box (L1) (Q):             0.00, 0.01   Jarque-Bera (JB):   247421.33, 374928.07
# Prob(Q):                        0.97, 0.94   Prob(JB):                     0.00, 0.00
# Heteroskedasticity (H):         1.25, 0.39   Skew:                       -1.38, -1.58
# Prob(H) (two-sided):            0.00, 0.00   Kurtosis:                   29.76, 35.97
#                            Results for equation y1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0004      0.001      0.365      0.715      -0.002       0.002
# L1.y1         -0.0498      2.295     -0.022      0.983      -4.548       4.449
# L1.y2         -0.0201      0.634     -0.032      0.975      -1.263       1.222
# L1.e(y1)    3.739e-05      2.295   1.63e-05      1.000      -4.498       4.498
# L1.e(y2)      -0.0011      0.633     -0.002      0.999      -1.242       1.240
# L2.e(y1)       0.0021      0.267      0.008      0.994      -0.522       0.526
# L2.e(y2)       0.0004      0.112      0.003      0.997      -0.220       0.220
#                            Results for equation y2
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0001      0.001      0.096      0.923      -0.002       0.003
# L1.y1          0.5654      3.267      0.173      0.863      -5.839       6.970
# L1.y2         -0.0741      0.796     -0.093      0.926      -1.635       1.486
# L1.e(y1)       0.0146      3.267      0.004      0.996      -6.388       6.417
# L1.e(y2)      -0.0322      0.796     -0.040      0.968      -1.592       1.528
# L2.e(y1)       0.0928      0.318      0.291      0.771      -0.531       0.717
# L2.e(y2)      -0.0131      0.150     -0.087      0.930      -0.308       0.281
#                              Error covariance matrix
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# sqrt.var.y1        0.0119   2.83e-05    420.240      0.000       0.012       0.012
# sqrt.cov.y1.y2     0.0037      0.000     36.340      0.000       0.003       0.004
# sqrt.var.y2        0.0148    3.8e-05    389.059      0.000       0.015       0.015
# ==================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
res.aic
print(n_test)
print(n_train)

asset = 0
#ljungbox = res.test_serial_correlation('ljungbox')
#print(ljungbox.shape)
#sm.stats.acorr_ljungbox(res.resid[:,0], lags=[10], return_df=True)
#sm.stats.acorr_ljungbox(res.resid[:,1], lags=[10], return_df=True)
np.random.seed(42)
print(res.resid.shape)
Xrand= np.random.rand(1000)
Xrandnot = np.ones(1000)+np.linspace(-1,1,1000)
df_lb = sm.stats.acorr_ljungbox(res.resid[:,asset], lags=list(range(1,1000)), model_df=myp+myq, return_df=True)
#df_lb = sm.stats.acorr_ljungbox(res.resid[:,asset], lags=list(range(1,1000)), model_df=myp+myq, return_df=True)
df_lb["lb_pvalue"].plot()

df_lb_base = sm.stats.acorr_ljungbox(X[:,asset], lags=list(range(1,1000)), return_df=True)
df_lb_base["lb_pvalue"].plot()
# Out:
# 1641
# 6561
# (8202, 2)
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error as mse
X_train, X_test = train_test_split(X, test_size=0.2, shuffle=False)
n,d = X.shape
n_train = len(X_train)
n_test = len(X_test)
max_p = 3
max_q = 3

AIC_store = np.zeros((max_p+1,max_q+1))
BIC_store = np.zeros((max_p+1,max_q+1))
TrainRMSE = np.zeros((max_p+1,max_q+1))
TestRMSE = np.zeros((max_p+1,max_q+1))

for pp in range(max_p+1):
    for qq in range(max_q+1):
        if pp==0 and qq==0:
            continue #no (0,0) model trained
        mod = sm.tsa.VARMAX(X_train, order=(pp,qq))
        res = mod.fit(maxiter=100, disp=False)
        AIC_store[pp,qq] = res.aic
        BIC_store[pp,qq] = res.bic
        
        #predictions
        Y_train = res.predict()
        res = res.extend(X_test)
        Y_test = res.predict(start=n_train, end=n_train+n_test-1) #end index is inluded too here
        
        #errors
        TrainRMSE[pp,qq] = np.sqrt(mse(Y_train,X_train))
        TestRMSE[pp,qq] = np.sqrt(mse(Y_test,X_test))

#print(AIC_store)
#print(TestRMSE)
print(np.unravel_index(np.argmin(AIC_store),np.shape(AIC_store)))
TestRMSE[0,0]=np.inf
print(np.unravel_index(np.argmin(TestRMSE),np.shape(TestRMSE)))
# Out:
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\worc3920\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:163: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# (3, 0)
# (0, 2)

# %%
#Next steps
#estimate best model
#verify independence of errors (Ljung-Box test? Engle ARCH test?)
#verify identical distribution (Kolmogorov-Smirnov test?)
#

# %%
Y = res.predict()
plt.plot(X[:,0])
plt.plot(Y[:,0])
#plt.plot((Y-X)[:,1],alpha=1)
#plt.plot((Y-X)[:,0],alpha=0.3)
n_lags=20
print(days)
#calling acf function from stattools
#lag_acf = pacf((Y-X)[:,1], nlags=n_lags)#, fft=True)
lag_acf = pacf(res.resid[:,0], nlags=n_lags)#, fft=True)
plt.figure(figsize=(16, 7))
#Plot ACF: 
plt.plot(lag_acf, marker="o")
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(X)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(X)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
plt.xlabel('number of lags')
plt.ylabel('correlation')
plt.tight_layout()
#pacf [4,6,9,10], [3,4]##seasonal 26,44,64,140 (delta: 18,20,68), 17,138
#acf [4,6,9,10], [3,4]##seasonal 26,44,64,140 (delta: 18,20,68), 17,138
# Out:
# 1

# %%
asset = 0
#x0 = X[X[:,asset]!=0,asset]
x0=(Y-X)[:,asset]
groups=3
gr_size = int(np.floor(len(x0)/groups))

Mu = np.zeros(groups)
Sigma = np.zeros(groups)

fig, ax_array = plt.subplots(groups)
for i, ax in enumerate(ax_array):
    x0i = x0[i*gr_size:(i+1)*gr_size]
    ax.hist(x0i, density=True,bins=np.linspace(-0.1,0.1,100))
   
    ax.set_xlim((-0.1,0.1))
    ax.set_ylim((0,70))
    Mu[i] = x0i.mean()
    Sigma[i] = x0i.std()

fig.subplots_adjust(hspace=1)
print(np.round(Mu,4))
print(np.round(Sigma,4))
# Out:
# [-0.0002  0.0004 -0.0002]
# [0.0099 0.014  0.0111]

# %%
############TIME SERIES FUN STARTS HERE ###################
#VARIMA p,i,q where lags are shifted by the investment horizon

#from statsmodels.tsa.statespace.varmax import VARMAX
from sklearn import linear_model
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression

def lagVAR(X_in, p=3, lag=int(days), alpha=1):
    #difference data
    n,d=np.shape(X_in)
    #print(n,d)
    #print(lag)
    
    #differencing updates X
    #for dd in range(d):
    #    X_in[dd:-1,:] = X_in[dd+1:,:]-X_in[dd:-1,:]
    #    X_in=X_in[:-1,:]
    #n -= i
    
    X=np.zeros((n-lag-p,d,p)) #data
    Y=np.zeros((n-lag-p,d)) #predictions
    for tt in range(n-lag-p):
        Y[tt,:] = X_in[tt+lag+p,:]
        X[tt,:,:] = X_in[tt:tt+p,:].T
      
    X = X.reshape((n-lag-p,d*p))
    #print(X.shape)
    #clf = MultiOutputRegressor(Lasso(max_iter=10**5, alpha=alpha))
    #clf = MultiOutputRegressor(Ridge(random_state=42,alpha=alpha))
    clf = Ridge(random_state=42,alpha=alpha)
    clf.fit(X,Y)
    #clf = linear_model.Lasso(alpha=alpha)
    #clf.fit(X,Y)
    return clf,X,Y

# %%
print(len(X))
lag=days
# Out:
# 17462

# %%
p0=1
alpha0=100
clf,Xtrain,Ytrain = lagVAR(X_in = X[:10000,:], p=p0, alpha=alpha0)
clf2,Xtest,Ytest = lagVAR(X_in = X[10000-days+1:,:],  p=p0)
clf_all,X_all,Y_all = lagVAR(X_in=X,p=p0, alpha=alpha0)

# %%
clf.get_params(deep=True)
print(clf.score(Xtrain,Ytrain))
print(clf.score(Xtest,Ytest))
#clf.predict(Xout[0,:].reshape(1,-1))

#Train
plt.plot(Ytrain[:,0])
plt.plot(clf.predict(Xtrain)[:,0])
plt.legend(["Data","Prediction"])

#Test
plt.figure()
plt.plot(Ytest[:,0])
plt.plot(clf.predict(Xtest)[:,0])
plt.legend(["Data","Prediction"])

#Residuals
plt.figure()
plt.plot(Ytest[:,0]-clf.predict(Xtest)[:,0])
# Out:
# 0.258048650247779
# -1.2468294867104444

# %%
print(clf.coef_)
#Plot Empirical distribution and error distribution'
print(X.shape)
plt.scatter(x=X[:,0],y=X[:,1],c='b',s=0.1)

residual = Y_all - clf_all.predict(X_all)
n_res=len(residual)
print(n_res)
plt.scatter(x=residual[:,0],y=residual[:,1],c='g', s=0.1)
plt.scatter(x=clf_all.predict(X_all)[:,0], y=clf_all.predict(X_all)[:,1],c='r', s=0.1)

print([Y_all[:,i].mean() for i in range(2)])
# Out:
# [[ 0.04777354 -0.0835358 ]
#  [-0.01344135  0.07654586]]
# (17462, 2)
# 11986
# [0.08373094147285123, 0.04405339861710764]

# %%
n,d=X.shape
ax = plt.hist(X.sum(axis=1)/d,bins=100,cumulative=True,density=True)
ax = plt.hist(residual.sum(axis=1)/d,bins=100,alpha=0.5,cumulative=True,density=True)
print(residual.mean(),residual.std())
print(X.mean(),X.std())


axes = plt.gca()
axes.set_ylim(0,0.1)
axes.set_xlim(-0.1,0.03)
plt.grid(True)
# Out:
# -1.363464285206266e-16 0.08081789264974233
# 0.07788313757796106 0.100861437823029

# %%
len(X)
from sklearn.base import BaseEstimator, RegressorMixin

class myAverage(BaseEstimator, RegressorMixin):
    def fit(self, X, y=None):
        return self
    def predict(self, X):
        n,d=X.shape
        p=100
        lag=15*365
        y=np.zeros((n-p-lag,d))
        for i in range(n-p-lag):
            for dd in range(d):
                y[i,dd] = sum([X[j,dd] for j in range(i,i+p)])/p
        return y

# %%
n,d=X.shape
print(X.shape)
print(15*365)
# Out:
# (6964, 3)
# 5475

# %%
print([i for i in range(1,2)])
# Out:
# [1]

# %%
p=100
est2=myAverage()
Y2 = est2.predict(X)
Y2.shape
print(days==15*365)
print(6000-days+1)
print(n-days-p)
print(n)
print(est2.score(X[6000-days-p:,:],X[6000:,:]))

#Observation
plt.plot(X[6000:,0],'b', linewidth=2)
#Prediction
plt.plot(est2.predict(X[6000-days-p:,:])[:,0], 'r', linewidth=2)
# Out:
# False
# 4176
# 5039
# 6964
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-470-01ca8a02d923> in <module>
#       7 print(n-days-p)
#       8 print(n)
# ----> 9 print(est2.score(X[6000-days-p:,:],X[6000:,:]))
#      10
#      11 #Observation
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     550         from .metrics import r2_score
#     551         y_pred = self.predict(X)
# --> 552         return r2_score(y, y_pred, sample_weight=sample_weight)
#     553
#     554     def _more_tags(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     587     """
#     588     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 589         y_true, y_pred, multioutput)
#     590     check_consistent_length(y_true, y_pred, sample_weight)
#     591
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      82
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     254     if len(uniques) > 1:
#     255         raise ValueError("Found input variables with inconsistent numbers of"
# --> 256                          " samples: %r" % [int(l) for l in lengths])
#     257
#     258
#
# ValueError: Found input variables with inconsistent numbers of samples: [11462, 7812]

# %%
alphas = np.linspace(0,100,20)
ps=np.linspace(1,100,10)
scores = np.zeros((len(alphas),len(ps)))
for aa in range(len(alphas)):
    for pp in range(len(ps)):
        clf,Xtrain,Ytrain = lagVAR(X_in = X[:10000,:], p=int(ps[pp]), alpha=alphas[aa])
        clf2,Xtest,Ytest = lagVAR(X_in = X[10000-days+1:,:],  p=int(ps[pp]), alpha=1)
        scores[aa,pp] = clf.score(Xtest,Ytest)

print(np.unravel_index(np.argmax(scores),np.shape(scores)))
print(np.max(scores))
#print(scores)
# Out:
# (19, 0)
# -1.2468294867104444
# [[-2.88147595 -2.87508026 -2.87532967 -2.8884138  -2.90131351 -2.912252
#   -2.92143253 -2.92806928 -2.93825725 -2.95577793]
#  [-2.45976531 -2.84332112 -2.86995571 -2.88175582 -2.89394632 -2.90792652
#   -2.92134131 -2.93281256 -2.94074972 -2.94983635]
#  [-2.2273088  -2.79793647 -2.85039761 -2.87174736 -2.88705026 -2.90217659
#   -2.91684937 -2.9300652  -2.94026712 -2.94981173]
#  [-2.06518347 -2.75482404 -2.82822769 -2.85897201 -2.87850539 -2.89553094
#   -2.91143603 -2.9259401  -2.9378072  -2.9483425 ]
#  [-1.94040797 -2.71452711 -2.8056373  -2.84492715 -2.86890188 -2.88819951
#   -2.90546132 -2.9211274  -2.93435704 -2.94591819]
#  [-1.83934883 -2.67687586 -2.78331349 -2.83031675 -2.85864071 -2.8803675
#   -2.89908789 -2.91588279 -2.930312   -2.9428591 ]
#  [-1.75493774 -2.64160997 -2.76151258 -2.81550455 -2.84798113 -2.87217735
#   -2.89241875 -2.91033643 -2.92586977 -2.93935602]
#  [-1.6829528  -2.60847611 -2.74033214 -2.80069179 -2.83709364 -2.86373616
#   -2.88552806 -2.90456789 -2.92114437 -2.9355284 ]
#  [-1.6206263  -2.57724746 -2.71980204 -2.78599481 -2.82609297 -2.85512444
#   -2.87847217 -2.89863157 -2.91620853 -2.93145544]
#  [-1.56602442 -2.54772571 -2.69992078 -2.77148244 -2.8150579  -2.84640307
#   -2.87129505 -2.89256743 -2.91111223 -2.92719242]
#  [-1.51773322 -2.51973868 -2.68067174 -2.7571955  -2.80404336 -2.83761841
#   -2.86403158 -2.88640619 -2.90589178 -2.92277957]
#  [-1.47468352 -2.49313692 -2.66203107 -2.74315761 -2.79308811 -2.82880604
#   -2.85670972 -2.88017214 -2.90057465 -2.91824722]
#  [-1.43604581 -2.46779049 -2.6439718  -2.72938149 -2.78221959 -2.81999342
#   -2.84935202 -2.8738849  -2.89518231 -2.91361889]
#  [-1.40116319 -2.44358599 -2.62646601 -2.71587283 -2.77145728 -2.81120185
#   -2.84197681 -2.86756055 -2.88973196 -2.90891327]
#  [-1.36950683 -2.42042416 -2.60948597 -2.70263268 -2.7608149  -2.8024479
#   -2.83459902 -2.86121239 -2.88423758 -2.90414549]
#  [-1.34064504 -2.39821772 -2.59300484 -2.68965903 -2.75030195 -2.79374448
#   -2.8272309  -2.8548515  -2.87871077 -2.89932801]
#  [-1.31422127 -2.37688965 -2.57699695 -2.67694784 -2.73992482 -2.78510163
#   -2.81988246 -2.84848719 -2.87316119 -2.89447119]
#  [-1.28993805 -2.35637173 -2.56143796 -2.66449373 -2.7296876  -2.77652712
#   -2.81256194 -2.84212728 -2.86759702 -2.88958378]
#  [-1.26754495 -2.3366033  -2.54630498 -2.65229047 -2.71959261 -2.76802697
#   -2.80527612 -2.83577839 -2.86202519 -2.8846732 ]
#  [-1.24682949 -2.31753021 -2.53157644 -2.64033132 -2.70964086 -2.75960573
#   -2.79803053 -2.82944612 -2.85645163 -2.87974583]]

# %%
print(alphas[19])
print(ps[0])
# Out:
# 100.0
# 1.0

# %%
for i in range(3):
    print(abs(np.round(clf.estimators_[i].coef_.reshape((3,10)),1)) > 0.1)
    print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-216-e2c59217c87e> in <module>
#       1 for i in range(3):
# ----> 2     print(abs(np.round(clf.estimators_[i].coef_.reshape((3,10)),1)) > 0.1)
#       3     print()
#
# AttributeError: 'Ridge' object has no attribute 'estimators_'

# %%
np.min(X)
# Out:
# -0.029604947994605113

# %% [markdown]
# We can now visualize the result to see how the MILP algorithm has segmented the distribution according to the VaR constraints:

# %%
def plotDistribution(X, m, V, alpha, i0=0, i1=1, names=["SP500","HSI"], cmap_str = 'gist_rainbow', markersize=5, fig_size=(8,6)):
    x1=X[:,i0]
    x2=X[:,i1]
    
    n_x=len(x1)
    d=2
    n_alpha=len(alpha)
    dropped=[[] for i in range(n_alpha)]
    kept=list(range(n_x))

    for aa in range(n_alpha):
        for vv in range(len(V[aa])):
            if m.var_by_name(f'z_{aa}_{vv}').x == 0:
                dropped[aa].append(V[aa][vv])

    fig=plt.figure(figsize = fig_size, dpi = 100)
    cmap=plt.cm.get_cmap(cmap_str,n_alpha)
    
    plt.scatter(x1[kept],x2[kept],s=markersize,c='grey')
    for aa in reversed(range(n_alpha)):
        plt.scatter(x1[dropped[aa]],x2[dropped[aa]],s=markersize,color=cmap(aa/(n_alpha)))
    
    plt.grid(True)
    plt.xlabel(names[0])
    plt.ylabel(names[1])
    plt.title('Annual returns')

    plt.gca().set_aspect('equal', adjustable='box')
    return x1, x2, cmap

# %%
x1, x2, cmap = plotDistribution(X[::skip,:], m, V, alpha, markersize=5)

# %%
def getEmpiricalDensity(data, xlim=None):
    n,d=np.matrix(data).shape
    df2=pd.DataFrame()
    for i in range(d):
        df2[f"value_{i}"]=data[:,i]
        # Frequency
        df2[f"frequency_{i}"] = 1

        # PDF
        df2[f'pdf_{i}'] = df2[f'frequency_{i}'] / sum(df2[f'frequency_{i}'])

        # CDF
        df2 = df2.sort_values(f"value_{i}")
        df2[f'cdf_{i}'] = df2[f'pdf_{i}'].cumsum()
        #df2 = df2.reset_index()

        # Plot
    fig, ax = plt.subplots()
    for i in range(d):
        df2 = df2.sort_values(f"value_{i}")
        if xlim is not None:
            df2.plot(ax = ax, x = f'value_{i}', y = f'cdf_{i}', xlim=xlim, grid = True, legend=False)
        else:
            df2.plot(ax = ax, x = f'value_{i}', y = f'cdf_{i}', grid = True, legend=False)

# %%
getEmpiricalDensity(pred_returns)

# %%
plt.scatter(x=pred_returns[:,0],y=pred_returns[:,1], s=5)
plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')

# %%
#print(z)
#getEmpiricalDensity(z[:,0])
#getEmpiricalDensity(z[:,1])

plt.figure(figsize = (12,8))
plt.hist(z[:,1],density=True, bins=10)
mu = 0
variance = 1
sigma = np.sqrt(variance)
x00 = np.linspace(mu - 5*sigma, mu + 5*sigma, 100)
plt.plot(x00, stats.norm.pdf(x00, mu, sigma))
axes = plt.gca()
axes.set_xlim(-5,5)
print(len(z))
# Out:
# 32

# %%
Xskip=X[::skip,:]
R = np.sort([sum(wStar*Xskip[i,:]) for i in range(len(Xskip))])
add_length=0.01
getEmpiricalDensity(pd.Series(R))
for i in range(len(VaR)):
    plt.arrow(x=np.min(R)-add_length, dx=VaR[i]-np.min(R)+add_length, y=alpha[i], dy=0, color=cmap(i/len(alpha)), length_includes_head = True,
                   head_width=0,head_length=0)
plt.xlabel('Empirical portfolio return')
plt.ylabel('Probability')
plt.title('Empirical cumulative distribution function of portfolio returns')

axes = plt.gca()
axes.set_ylim(-0.02,0.12)
plt.show()
